# %%
#ユーザーのツイート
# !pip install tweepy

# %%
import json
import tweepy
from datetime import datetime,timezone
import pytz
import pandas as pd
import datetime

# %%
username = "Tsutsui0524"
count = 4000

# %%
f = open('secret.json','r')
key = json.load(f)
Consumer_key = key['Consumer_key']
Consumer_secret = key['Consumer_secret']
Access_token = key['Access_token']
Access_secret = key['Access_secret']
bearer_token = key['bearer_token']

# %%
def get_userid(username):
    username = username
    user_result = client.get_user(username=username)
    id = user_result.data.id
    return id
def change_time_JST(u_time):
    tm = u_time.astimezone(pytz.timezone('Asia/Tokyo'))
    zn = tm.strftime('%Y/%m/%d %H:%M:%S')
    return zn
def csvize(tw_data,text,labels,name):
    name = name
    #tw_dataのリストをpandasのDataFrameに変換
    df = pd.DataFrame(tw_data,columns=labels)
    #CSVファイルの名前を決める
    file_name=name + '_'+text+'_'+time_now+'.csv'
    #CSVファイルを出力する
    df.to_csv('file/'+file_name,encoding='utf-8-sig',index=False)
   
dt_now = datetime.datetime.now()
time_now = dt_now.strftime('%Y%m%d%H%M%S')

# %%
# v1認証
auth = tweepy.OAuthHandler(Consumer_key, Consumer_secret)
auth.set_access_token(Access_token, Access_secret)
api = tweepy.API(auth)
# v2認証
client = tweepy.Client(
    consumer_key=Consumer_key,
    consumer_secret=Consumer_secret,
    access_token=Access_token,
    access_token_secret=Access_secret,
    bearer_token=bearer_token
)

# %%
user_id = get_userid(username)

# %%
tw_data = []
next_token = ""
first_flg = True

while True:
    print("first_flg: " + str(first_flg))
    if first_flg == True:
        #1回目リクエスト    
        tweets = client.get_users_tweets(user_id,tweet_fields='public_metrics')
        first_flg = False
    else:
        #2回目リクエスト    
        tweets = client.get_users_tweets(user_id,tweet_fields='public_metrics',pagination_token=next_token)
    try:
        next_token = tweets[3]['next_token']
        # print("next_token: " + next_token)
    except KeyError:
        #next_tokenが取得できない（最後のリクエスト）の場合はループ終了
        print("最後のページに到達しました")
        break
    for tweet in tweets.data:
            tw_data.append([
            tweet.id,
            tweet.text,])
            print(tweet)
print(f"取得したデータ数：{len(tw_data)}")
# Out:
# first_flg: True
# RT @act31hiroki: いや、バレるてwww
# RT @Bug1978: 以前、作成したEXCELのテーブル（ListObject）を数式お残して初期化する関数です。
#
# ClearTable(Sheet1, "テーブル1")
#
# 使い方はこんな感じに、テーブルのあるワークシートと、テーブル名をパラメータにしてコールしてください…
# RT @UuGESZJ40BfKVSP: 私は
# ・セルB2に数式を入れる
# ・B2をコピーしてB3〜B11までコピペする
# って構造にしてた…(°▽°;)
# @sugoi_kaizen 吉田先生のセミナーを受けてもらっていれば…ッ
# @aero_iki さすがのご指摘です！！
# 良い記事は本当に、変えた設定を戻すとか細かいのですよね～
# RT @sugoi_kaizen: なので「初期化が大事」「一旦既存データは消す」のが大事とうちのVBAセミナーでは何度も繰り返します。
# RT @aero_iki: 配列を一括でシート上に出力する処理とかが最たる例かな。
# 「配列を一括でシート上に出力する」のタイトルで書かれた記事がいくらかあるけど、初期化について言及されていない記事は実務を知らないニワカなので注意。
# RT @Pythonist19: 「このプロンプト、表現変えてみたら」に変わるだけじゃ
# @icedblack2 わたしも出だしは「ドュフフ」なので、こうはならないです！笑
# @blanknote そっち！？
# その発想はありませんでした…笑
# first_flg: False
# #ExcelVBA のセルに関数を入れるのに
# Formula使ってA1形式で書くと参照セルが変わってくれるのを知った時、ずっとFormulaR1C1使ってR1C1形式で書いてたので、損した気分になりました
# （図の例だと、全部セルA2参照になると思ってました） https://t.co/u4wNmOzlwG
# データをシートに一旦書き出して処理するマクロで、一旦書き出すシートのデータ削除の処理が入ってなくて、前回処理した件数が今回処理する件数より多い時に、末尾に前回のデータが入り込む欠陥を発見しました
# @TAKAMAN02345158 日本の車は壊れないので…（違う）
# @takeshi741 正直、割れるだろうとは思っています…笑
# @yakku_BTC その視点が抜けていましたね…笑
# @juke_sympho なるほど、たしかに…
# ChatGPTが奪う光景 https://t.co/wSleeA8eHa
# RT @kuroneblog: サンバルカン🤣🤣🤣
# @igz0 うおおおおおおお！おめでとうございます！！！
# 2.2万フォローありがとうございます
#
# HLOOKUPちゃん、横検索カニ歩き
# #関数ちゃん https://t.co/IIfLQCurUH
# first_flg: False
# @mechkawa そんなに良いですか！
# 観に行きたくなりました！
# RT @Tsutsui0524: 齋藤の「齋」の中身がサンバルカンでもバレない説 https://t.co/Q67w824FeB
# @CR318tsuru 間が埋まって良いですよね
# @ticktackworker 厳しいのを頼みます！！
# @nitoukinnosuke うらやまー！
# 美味しそうです！！
# @YUExcelMARU おおお！！
# 関数ちゃんはアクスタ向きのイラスト多いので是非やりたいですね！
# 教えてくださってありがとうございます！
# WEB会議の謎
# 「こちらの資料をご覧ください…ヨイショ！」
# 子供が英語の恐竜の動画を見てるので「英語だけどいいの？」と聞いたら「恐竜の鳴き声は一緒だからいい」とのこと
# そういうものなのか…
# @4qMTHtdVh0UcB2b 関数との出会いが色々変えてくれることありますよね
# 私も先人には感謝しています！
# RT @4qMTHtdVh0UcB2b: 文字列操作関数の存在を知った2008年。解決できないと思った問題が、一気に解決。パワハラ案件を跳ね除けられたのだ。これを教えてくれた方は、他界してしまった。今でも感謝している。#Excel#文字列操作関数#left関数
# first_flg: False
# @kazu_shindo カズヒコーキさん、ありがとうございます！
# 6章でいったん締める構成だったので、力を入れたところでした！
# 刺さって良かったです！！
# レビューたくさん頂けて嬉しいです
# ありがとうございます！ https://t.co/nzcPpmU4we
# @yosatonet あー、このコマンド！！
# @TETRA_IT 黙って矢文
# @37nfZ9bQuPMQJnA これです！
#
# https://t.co/1YbS66XW5X
# 良いこと言ったつもりのところが刺さってくれて良かったです！！
# やったー！ https://t.co/Vn2nJt31zV
# RT @nackie_u: トムヤムクン噴いたwww
# @37nfZ9bQuPMQJnA 私はボケてで知ったんですよね
# 幅！高さ！奥行き！
# だったような
# 齋藤の「齋」の中身がサンバルカンでもバレない説 https://t.co/Q67w824FeB
# =LEFT("たいやき",2)
# ↓
# たい
#
# LEFTちゃんは、たいやきを頭から食べるタイプ
# #関数ちゃん
#
# LEFTちゃん紹介記事
# https://t.co/j8IaI8GCs9 https://t.co/Zh4eRvp5sJ
# first_flg: False
# @KotorinChunChun そういうお話は頂いてないですね〜！
# アピールしないと！
# @DemodoriGatsuo おめでとうございます！！
# ガツオさん、半端ない！！
# 趣味でExcel関数を擬人化したキャラクター（#関数ちゃん ）を描いています！
#
# #三億アカウントの中から私を発掘してください https://t.co/b66I8O8Fsa
# @sasetsu_HG めちゃくちゃ可愛いです！！
# RT @Tsutsui0524: ヒーローがマントを羽織るのは！
#
# キュアスカイのデザイン、とても素晴らしいと思うのです
# #プリキュア
# #precure https://t.co/cGOYJGfyIO
# RT @Tsutsui0524: Excelのセルに入力するとプリキュア放送までの時間を表示してくれる数式
# わえなび先生考案(@waenavi_jp)
#
# =MOD(65/48-NOW(),7)
#
# セルの表示形式は[h]:mmに設定しましょう！
#
# #Excel
# #プリキュア #p…
# @Skillup_VBA おめでとうございます！
# @9pw95IlW6KsWoGa ばんばんさん、ありがとうございます！
# 最寄りの本屋さんに置かれていますように…！
# 応援励みになります！
# @KotorinChunChun ほんとQRコード優秀すぎて笑
# @satovba7 レアな仕訳に戦慄が走ります笑
# first_flg: False
# @TaniponVBA これはどこがポイントなんですか？
# RT @audrey_10_6: 上下反対でそのまま送ってくる人の神経がわからん
# RT @tommie_tommie_a: OCR処理したら自動的に回転します。
#
# うまく読めた場合に限りますが。
# @TETRA_IT これはガリ！
# @ObonneF ボンヌさん、ありがとうございます！
# 私自身、関数を知らなかったために不要な列を作ったり、変に組み合わせたりしていたので、知ることのハードルを下げたいという思いでした！
# @haine_2020other モニター倒して物理ですか笑
# RT @ObonneF: 仕事でexcel使うけどあまり知識がなくて、とっつきやすそうな本がきたぞ！！と購入。パッとすぐには使えないんだけど(私が引数を文字だけでは理解できないので)SUMIFちゃんのことを思い出して昨日から助けてもらってる。とてもたすかる。
# https://t…
# スキャンしたPDFは読める向きに直す！！ https://t.co/ZZnIBaUfRB
# @wafu_spaghetti イタリア料理店のキッチンでこれからはパスタを…？笑
#
# 新しいステージ、頑張ってください！！
# @mikimomo_as いやまぁ、私的にも色々思うところはあるので平気です！！
# 反省するところは、反省しないといけませんけど！
# first_flg: False
# @mikimomo_as ありがとうございます！
# 軽く読みましたが…光希桃先生とは色々とお話したいです！
# 電卓 &amp; そろばん
# エクセル &amp; 電卓
# AI &amp; エクセル（？） https://t.co/GnA85yFF3z
# @charoid_ai これはいいですね！
# @usamiko 一回回すお金でどれだけ買えると思っているんだ笑
# これ
#
# [Shift]+[F8]を押してから選択
#
# こっちはセル範囲のときと1セルのときで挙動が違う謎があったような… https://t.co/B5bXzt2B5o
# 当座預金と当座借越も是非…！ https://t.co/wiZtWmwWuS
# @Hiro_officewrkr そんなデスクあったら入り浸り確定です
# @Hiro_officewrkr それ、私の本も入ってますよね？笑
# RT @penkun583: 怪しい日本語！！！
# でも語感大好き https://t.co/t9x9cJBYn7
# @s5ml チェック入れないと投稿できないとか笑
# first_flg: False
# RT @Tsutsui0524: めちゃくちゃ面白かったです！
#
# ・紹介している関数が多い
# ・重複しない順位を作る数式を扱っている
#
# ツボ：
# 「過労死兆星」
# 「キーボードを突く」
# 「電卓より優れた計算方法など存在しねえ！」
#
# #広告
# 世紀末救世主伝説 エクセル関数北斗百列拳…
# @RelaxTools クリスタ良さそうですよね〜
# 株持ってて使い続けられるなら、悪くないなと笑
# セルシスの株主優待
# 今だと68,000円か〜 https://t.co/znRTocCjfK
# RT @Tsutsui0524: INDEX MATCH
# #関数ちゃん
#
# フォロワー数1.5万人になりました
# これからもよろしくお願いします https://t.co/H78Pm6AG4r
# 上司の顔色をうかがう時代から、AIの顔色をうかがう時代へ
# @air_bento_ya 招待制でしたっけ？
# 懐かしいですね〜
# @IT_craftmanship ありがとうございます！
# エンジニャーではないですが、Fさんの感触が悪くない本なら読みたい…！
# @IT_craftmanship もしよかったらタイトル教えてください！
# RT @_EikoShimomura_: Excelのセンスが致命的に無いんだけど、このブログは分かりやすかった。
# @IT_craftmanship 気になります
# first_flg: False
# 日本の企業がTwitter作ったら、アカウント開設と同時に公式がフォローしてくれてフォロワー0の状態にならない、みたいなことしてくれそう
# @mine__0 @chome2xx それくらいの感覚ですよね
# 今も理屈が全てわかってる訳ではなさそうな
# @chome2xx これの理屈が最近までよく分かってなかったというのだからビックリですよね
# NOWちゃんの記事、イラスト変えたり追記したりしました
#
# NOW関数 擬人化キャラクター解説！エクセル関数の機能や使い方を図やイラストでかんたんに説明します！ https://t.co/GLoGKykHg9
# RT @matsbox: 🗓暦の擬人化　春分の日編
#
# （今年の春分の日は3月21日でした！）
# #暦の擬人化 #拝啓暦の上から https://t.co/cxqXzKmsaa
# RT @a_ranking_news: (3/24) honto 電子書籍ストアランキング &gt; コンピュータ・IT・情報科学 &gt; ソフトウェアランキング5位:筒井.xls『関数ちゃんと学ぶエクセル仕事術 実務で役立つExcel関数を擬人化したら？』
# https://t.co/a…
# RT @yu_38s: ほんとそう！
# #Excel の裏技覚えるみたいで便利！
# RT @Tsutsui0524: 久しぶりにブログ更新しました！
#
# IF関数ではワイルドカードが使えませんが、COUNTIF関数と組み合わせて使う数式を紹介しています！
#
# =IF(COUNTIF(B2,"営業*")&gt;0,"営業部","")
#
# #関数ちゃん
# 【エクセルTips】I…
# @Yakiniku_Soda_ えっ、それは詐欺にはならないんですか
# @tako_and_kitune 正しいですね〜
# first_flg: False
# RT @furyutei: 筒井.xls「関数ちゃんと学ぶエクセル仕事術 実務で役立つExcel関数を擬人化したら？」 (できるビジネス) https://t.co/NJhU8KQnl7 #ad
#
# うちにも本日届いてました～入門させていただきます(笑)
#
# 筒井さん @Tsut…
# @ksgiksg 週明けの姿が目に浮かぶようだ
# @RazorEdge2077 克典さん、ありがとうございます！
# 機能に愛着が湧きます！
# @maruru17436913 @johnchung1975 えっっ
# @nitoukinnosuke 懐かしい！
# ジムに潜入するときでしたっけ？？
# RT @nitoukinnosuke: おまけ
# 分かる人いるのか？
#
# #アニポケ https://t.co/o49FGFpSWn
# 「新入社員よExcelを勉強しろ」では不十分
# 勉強で得た知識は周囲に隠しておこう
# そして見せるタイミングは慎重に選ぼう
# @ksgiksg 2日もある！！
# なにしよっかなー！！
# @giniro4 期日の列を追加したり、残り日数の列を追加したり、チェック済みの列を追加したり、チェック済みの列を追加したり、連絡済みの列を追加したり、チェック済みの列を追加したりですかね…
# トライアル期間は百発百中だったOCRソフトが、導入したとたんに精度が下がったのでトライアル期間は人力だった説が浮上している
# first_flg: False
# @Delicatessen38 列追加するのではなく既存の列に機能を追加…それは危険なムーブ…
# 私は引き継ぐときにABCのようなツッコミが入らないように、自分が担当の時以上に便利にしようとするタイプですね
# それで、渡すのがちょっと惜しくなってしまうことがあります笑 https://t.co/Q1Qvxbjzqw
# Excelのステータスバーを右クリックするとCapsLock、NumLock、ScrollLockの状態が表示できます
# なんとクリックしてもLockの状態は変えられず、ただ状態を表示するのみです
# 残念…！！ https://t.co/zRAYytnjVT
# @geinin 便利機能も使われなくては…
# @mine__0 期間のクオーターという説を見たことがあります
# @TempemLoid そういうの保守する人に仕事回ってくるんですよね～
# 上司、ミスの再発防止策でエクセルの表に列追加しがち
# 企業「今後のご活躍を心よりお祈り申し上げます」
#
# 超大型就活生「自分の目で見てみたいとは思わんかね？私の、今後を」
# Q1 Q2 Q3 Q4 Q1 Q2 Q3…
#
# オートフィルは実行後のチェックもセットで！ https://t.co/gPxj5qg2Yp
# first_flg: False
# @RPA_Journey 孤独ですよね…
# @s5ml たまにあるガチのやつでした笑
# Excelマクロ直った…
# 今まで使えていたマクロが突然使えなくなって、エクスポート、インポート、マクロの記録を行うと回復するという謎現象でした
# @IT_craftmanship うまぁい
# @N_noir_7 言語というツールの使いこなしがイマイチに感じました
# @furyutei いやもう、こんなツイートに付き合わせてすいません…笑
# 種「あつくなって、つい芽が出てしまった」
# @ayutimali 次からそれ試します…！！
# WaasMedicの存在しりませんでした
# @ayutimali シャットダウンするとまずいんですか…！？
# 無効にするとまずいとかではなく、電源落とすのが良くないということでしょうか
# RT @fanatic008: 仕事柄すぐにイメージできたけど、その後のリプが秀逸すぎてめっちゃ楽しくなったw
# とりあえずC4だけでいいけどCなら被害でかいねw
# first_flg: False
# @StudykExcel どうやったらこんなに記事が量産できるんですか！？
# 見習わなくてはと思いつつ、真似できる気がしません…！
# @TETRA_IT まるでベンチャー社長のバーゲンセールだな…
# ※着ている社長は付属しません
# 今日は何もしてないのに壊れたExcelの修理…
# 何もしてないのになぁ…
# @omiso_seal なによりです！
# RT @AruF0nt: 将来有望すぎ
# RT @moripro3: 入社前に覚えておきたい一覧🌸
# RT @matudakta: おはようございます！
# おはようございます！！
#
# 筒井さんの関数ちゃんを買いました！
#
# https://t.co/0uuH5HCv5s
#
# 「筒井.xls」の読み方を知ってちょっと驚きました。
#
# 裏表紙から背表紙まで楽しめます！ 笑
#
# いろいろ仕掛けが…
# RT @Tsutsui0524: こども「障子破っちゃった…」
#
# 親「どこ！？」
#
# こども「セルで言うとC4」
# RT @impress_corp: ／
# 『関数ちゃんと学ぶエクセル仕事術』
# まえがき～第1章 無料公開キャンペーン
# ＼
#
# 新刊の一部が無料で読めちゃう！
# 擬人化されたExcel関数たちと一緒に楽しく使い方を学びましょう！
# 3月31日まで✨
#
# #無料公開 #Excel関数
#
# ht…
# RT @a_ranking_news: (3/23) honto 本の通販ストアランキング &gt; コンピュータ・IT・情報科学 &gt; ソフトウェアランキング2位:筒井.xls （著）『関数ちゃんと学ぶエクセル仕事術 実務で役立つＥｘｃｅｌ関数を擬人化したら？ （できるビジネス...…
# first_flg: False
# RT @shii___0530: こういうの見ると授業真面目に受けててよかったってなる
# 領収書を書いてもらう時、めんどうじゃない…？？ https://t.co/lrCudQ5LnZ
# 『入力時メッセージ機能』
#
# セルを選択した時にポン！とメッセージを表示する機能（コメント機能ではない）、入力時の注意事項や、リストを表示できて便利です！
#
# 他の人が使っていたので真似しようとしたら、なかなか情報にヒットせず苦労しました…
#
# 解説ブログ記事
# https://t.co/KREMPRX2Zz https://t.co/SebFEChMRm
# RT @Sakurada_U: このツイートもこのリプ欄も好きすぎる
# 春のExcelショートカットキー一覧
#
# 一覧を眺めると「こんな機能あったんだ！」とか「ショートカットキーあったんだ！」と、発見がありますよね
# 以前は目に留まらなかったものが、今は目に留まったり…！
#
# 時々眺めると、発見があるかもしれません！ https://t.co/vYFwfyQtoh
# RT @fukarakaru: webアニメーションの記事を更新しました。
# 「Web Animations APIのシンプルな使い方」。
#
# JavaScriptを使って、CSS/SVGのアニメーションを操作する仕組みです。
# サクッと実装できる方法を紹介。
# #javascript…
# 受講したい… https://t.co/15ix3Mezg4
# MARUZEN&amp;ジュンク堂書店 梅田店様(@mjumeda)
# ありがとうございます！！ https://t.co/GZQo33le1z
# @toshi81350036 さすがとしじさん！
# RT @Tsutsui0524: 今、逆に売れそう https://t.co/nbzkYFUvJS
# first_flg: False
# @yolozyaTOM 求道者ですね！
# @siecov 筒井味を感じ取ってくださりありがとうございます！
# RT @toshi81350036: あ、これバズるやつだ😎✨
# @toshi81350036 さすがです
# @siecov これ結構言われます…！！
# ジャンル的にステッカー付きは難しそうですよね笑
# RT @matsbox: 春爛漫！🌸
# 創作/再掲 https://t.co/NH1qdpjs2R
# @smskn らむおさん、ありがとうございます！
# XLOOKUPのセリフは頑張って考えたので嬉しいです！！
# RT @smskn: 読了でございます。
# ストーリー仕立てで、圧倒的読みやすさがこの本のウリだと思います。実用的な関数がピックアップされてるから、早速明日から使えちゃうしね。
# 一番のお気に入りは、XLOOKUPちゃんの決めセリフ😉 https://t.co/YkEpFlJZet
# 会社に届いた請求書の企業ロゴが横にびよ～んと伸びていて「列幅変更に引っ張られたんだな」と推理した
# (Excel製だったんだ…)
# @Kuroi_CPA 工場経理は必読の書になりそうな予感がします…！！
# first_flg: False
# RT @madarame_bco: こういう表現する子どもは大歓迎
# @nyanko_super 文句の付け所がない神対応です
# RT @nyanko_super: インターネットが壊れちゃった！助けて！
#
# はいはーい、これがインターネットですよー(アイコンだけIEに変えたEdgeをYahooをhomeに設定して起動する)
# 趣旨を理解していないスレ主
# 『侍ジャパンのメンバーで打線組んだったｗｗｗｗｗ』
# @ankoromochi7793 相互リンクおねがいします！
# @okkun_oosaka F1キー連打したのかと！
# @Excel_xlsx 著者として青りんごさんが得るものがあるとは思えないという…笑
# @ankoromochi7793 おめでとうございます！！
# 私もブログ頑張らねば！！
# @IT_craftmanship 実際そういうタイプは副業でもしっかり稼げそうですもんねえ…
# ぶら下がり根性の人間の世話まで見てられないっていうのは、そうでしょうね
# @marustudio えどげ～…
# first_flg: False
# RT @hassy_birow: 弊社では「青いアルファベットのeマークあったよね？あれがリニューアルしたのがこれ(edgeアイコン)なんよ」といわないとダメですね(特定の人)😇😇
# Edgeのことを「新しいインターネットエクスプローラー」と言うと、すんなり伝わることがある
# @Bug1978 便利な関数をいきなり与えられるから戸惑うんですかねえ
# 関数化、すすめていきます！！
# @yakku_BTC セル結合はアカン
# @na_da513302 @yakku_BTC 串刺しなんて上級テク使われたら…笑
# こども「障子破っちゃった…」
#
# 親「どこ！？」
#
# こども「セルで言うとC4」
# 最近、コミュニケーションで悩んだことがあったので一刻も早く発売して頂きたい… https://t.co/98hVlNd4Xi
# RT @SGTY24: IFERROR知らんくて、いつも IF(ISERROR(～),～,～) って書いてた…(´･ω･`)
# RT @nycity1022: 「実践　手入力」がもし本当に出版されたら、の目次案を作成してみた。こんな感じだろうか。何となく某有名技術書出版社風の目次にしてみた…つもり。 https://t.co/tGBHCbcSv4
# RT @YrkD05: 聖徳太子のメンタルどうなってんの？
# first_flg: False
# 「この関数便利そう！試してみよ！」
# っていう時にバージョン足りてない時のもどかしさ…
#
# Excel関数バージョン対応表です https://t.co/JiKi8Jas1v
# RT @matsbox: 🗓3月22日（水）
# 🗒旧暦閏2月1日・己卯・つちのとう
#
# 旧暦では、昨日が2月晦日。ということは今日から3月…ではなく、今年は閏（うるう）月でもう一回2月がスタート！
#
# 現在の七十二候は「雀始巣（すずめはじめてすくう）」で、道端のチュンたちを応援したく…
# AIに「指摘するから、何か間違ったこと言って」と頼んだら断られました
# このプライドを見習ったほうがいい
# RT @Tsutsui0524: 書籍をご購入いただいた皆様へ
#
# 現時点で2点、誤記が判明しています
# お詫びと訂正をご確認いただきますようお願い申し上げます
#
# あと6章扉イラストの虫眼鏡が欠けてしまいました
# 申し訳ございません
#
# 関数ちゃんと学ぶエクセル仕事術 https://…
# RT @impress_corp: おはようございます🌞
# 週末にもお知らせしましたが、『関数ちゃんと学ぶエクセル仕事術』の一部無料公開を3月31日まで延長しています！
#
# 見逃していた方も今からぜひご覧ください！
# それでは本日もよろしくお願いします。
# @KotorinChunChun ちゅん先生、ありがとうございます
# ヨドバシはチェックしてませんでした…嬉しいですね〜！
# @koikoi_kkk こんなのずるい！！笑
# 聖徳太子専用スマホOS https://t.co/GYrFRv2nE2
# @neko_shark9 鳩さん、ありがとうございます！！
# 勉強楽しい…とても嬉しいお言葉です！！
# VBAはコードが上から順番につら～っと処理・計算される線のイメージで、関数はこう、バン！！っていう点のイメージ！
#
# 計算の時系列が同時みたいな…関数が難しく感じる原因なんじゃないかと思ってますが…どうなんでしょう
# first_flg: False
# @mine__0 bingさん回答ですが https://t.co/LMJBcwlTUy
# PC：何もしてないのに壊れる
# 人間：何もしてないのに疲れる
# RT @zodiac_aq: 「会議では◯◯と言ったけれど書くな」
# 「◯◯は△△と書いておけ」
#
# 等もブラック企業議事録あるあるかも😇
# 役員から聞いたこともないRPAを紹介されたので、代わりにPADを勧めた
# @blue201507 ありがとうございます！
# IFERRORちゃんが頑張っていますね笑
# @mikimomo_as 果たしてそれで良いのかという問題はありますが…笑
# 私のブログはやっぱり関数ちゃんがいるのが特徴なのでCOUNTIFちゃんに一言登場してもらいました！
#
# 以前SUMIFを1セルで…というのを見かけてなんじゃそりゃと思ったのですが、今回の用途はアリな気がしています
#
# 省略の式かっこいいですよね！
# @vvqe1ji6kYe7e6p おめでとうございます！
# RT @satokenr: オライリーｗｗｗｗ
#
# すごくためになることが、やたらと小難しく書き記されていそうｗ😂
# 17世紀ごろまで西洋諸国が負の数という概念に抵抗を示していたらしいので、簿記が負の数を使わずに貸借(左右)でなんとかする仕組みなのは自然に思える
# RT @tanaka4412: 市だと四日市市とか市川市にやられるやつだ！🙃
# first_flg: False
# 久しぶりにブログ更新しました！
#
# IF関数ではワイルドカードが使えませんが、COUNTIF関数と組み合わせて使う数式を紹介しています！
#
# =IF(COUNTIF(B2,"営業*")&gt;0,"営業部","")
#
# #関数ちゃん
# 【エクセルTips】IF関数でワイルドカードを使う！？ https://t.co/xhtr52KiXJ https://t.co/k7e8givZD6
# セルA2の住所から県名を抜き出す数式
#
# =LEFT(A2,3+(MID(A2,4,1)="県"))
#
# 『◯◯県』に『県◯市』があった場合に『◯◯県県』を返すことが危惧されますが、『県』という漢字を含む市は岐阜県山県市のみ、東京23区に『県』から始まる区が無いので大丈夫です！ https://t.co/XVZNQIOy0m
# @sugoi_kaizen い、一体何が…
# @ankoromochi7793 サインいくらでも書きたいのですが…笑
# @ticktackworker 好きな画風です…良い！！
# @shintaro_sprech エンドミルの製造ラインですか！
# エンドミルひとつとっても奥が深そうですよね
# 直接加工物に触れるものなので品質の基準が厳しそうなイメージです
# RT @dekirumonn: MARUZEN＆ジュンク堂書店梅田店様で｢関数ちゃんと学ぶエクセル仕事術 実務で役立つExcel関数を擬人化したら？」をどどーんと展開中♪先週、新たに関数ちゃんのパネルを追加したんだもん！是非、見に来てほしいんだもーん🌸
# #関数ちゃん　#Exce…
# エンドミル！！
# 購入品の摘要欄に何度入力したことか…！！ https://t.co/l0WioJgjpz
# RT @nama_anal_fan: オライリーってわかると面白いやつ
# Excelでのファンクションキーの使い方はこの本で学びました
# 紙面も詰め込みすぎず読みやすいです！！ https://t.co/gdvodQrAo5
# first_flg: False
# @nijino_dqx おめでとうございます！！
# RT @Tsutsui0524: 最近Twitter低浮上気味でしたが、書籍執筆のために時間がとれなかったためでした
#
# ここ数カ月は本文・サンプルを考え、キャラクターをデザイン、イラストを描き…と多忙に過ごさせて頂きました
# そんなこんなで #関数ちゃん 本が3/14に発売します…
# @8Us5OgOadbEjKwJ 花楽さん、ありがとうございます！
# 擬人化にはこだわりました
# 布教頂けると幸いです！！
# @actiolic お役に立てて何よりです！
# @Momiji_DD511801 これ逆算でLINEのお友達の数バレるやつですか
# 特に支障もないですけど笑
# @Momiji_DD511801 -2150になりました
# 納得はしています
# @koikoi_kkk これが動画で言っていたやつですね笑
# @ExcelVBAer 踊るさん、ありがとうございます！！
# 息子さん片手に…素晴らしいですね
# @ymmox 同じような経験したことありますけど、しばらく頭から離れなかったです
# このイラストは成仏させたくて描いたものと推測いたしました笑
# 今、逆に売れそう https://t.co/nbzkYFUvJS
# first_flg: False
# @ankoromochi7793 うどんじゃないんですね笑
# いただきます！！
# @ankoromochi7793 おつかれさまでした
# @RPA_Journey おめでとうございます！
# おつかれさまでした！
# @kinasato_mochi おめでとうございます！
# @ino_dev 暴言に暴言返してるだけだからヨシ！（？）
# @ellnore_pad_267 無言なのがまた笑
# @satovba7 私もこれ悩んでます！！
# だいたい一緒ですよね〜
# @saitomoko なんだってー！？
# @bianchi_kab びあんきさん、ありがとうございます！
# 関数ちゃんプロフィールからというのは、良い順番ですね！
# NOWちゃん推しありがとうございます！
# @wa_maru_gm まるさん、ありがとうございます！！
# first_flg: False
# RT @Tsutsui0524: 無料公開の期間が今日までになっていましたが、好評により月末まで延長となっています！
#
# そりゃ試し読みしてみないと相性も分からないですよね！笑
#
# 『関数ちゃんと学ぶエクセル仕事術』まえがき〜第1章 無料公開キャンペーン - インプレスブックス h…
# CONCATちゃんが増えてる…！！
# MARUZEN＆ジュンク堂書店梅田店様、ありがとうございます！ https://t.co/GZQo33le1z
# @sugoi_kaizen めっちゃ推しを感じました！！
# なんか私も嬉しかったです笑
# 吉田先生（@sugoi_kaizen ）の本に手書きのポップと付箋つき見本ですごい神店舗…！！ https://t.co/AJZWt79OeT
# @SoutaSecure Soutaさんありがとうございます！
# 読まれますように！
# @IT_craftmanship @matudakta いやいや、そんなつもりは！
# 中小企業だと『海外拠点で現地採用する外国人に部長以上の給料が提示できないから採用できない』とか起きてそう
# RT @Tsutsui0524: 部下「議事録できました。ご確認お願いします。」
#
# 上司「どれどれ…あ、ここ会議後の雑談で変更になったから修正して」
#
# 部下「議事録では…？」
# 『 Windows + Shift + S 』
# 指定範囲のスクリーンショットを撮影してクリップボードへ送る
#
# 『Ctrl + V』や『Windows + V』で貼り付け可能な状態になります
# 範囲指定モードの時に方向キーを押すと位置の微調整、Ctrlキーで始点・終点を確定します！ https://t.co/LPLaRMSZq1
# @ksgiksg ローコード…
# first_flg: False
# @souring001 フル拝見しました
# 面白かったです！
# @KotorinChunChun これは、いい笑
# おめでとうございます！ https://t.co/8HfSAfP2pi
# RT @ticktackworker: 50レビューに到達しました✨
#
# 手にとってお読みいただいたうえに、星まで付けてくださって本当にありがとうございます🙌
#
# これからもレビューを踏まえて改善してまいります。
#
# https://t.co/iZc1pW1jcW
# @ma_anago すごい納得しました…笑
# あれはやばい粉です…
# @glucosamineZ 森田貢士先生ありがとうございます！
# ちゃんとKindle版も出ている…！！
# RT @glucosamineZ: そいえば関数ちゃん本のKindle版を購入しました！
# 勉強しよう😊 https://t.co/lTnbMImEmQ
# @Excel_design_Dr Excel医先生、ありがとうございます！
# どういう層に読まれるのか、気になるところです笑
# RT @keirinoishida: 上手いこと言いますねｗ
#
# 毎月同じ業務を飽きずにできる経理マンは『飽きない奉行』ですかね？
# @hy_11 ヤススさんありがとうございます！！
# 書店に自分の本があるのは不思議な感覚です！！
# first_flg: False
# RT @Excel_design_Dr: 関数ちゃんと学ぶエクセル仕事術 実務で役立つExcel関数を擬人化したら？
#
# 読んだ！これまでになかった全く新しいExcel本。まさかのExcel関数の擬人化！会話形式でネタ満載で面白おかしくExcel関数を学べます。コラムが共感の嵐👍…
# 遥かな未来ー
#
# 人類はAIに仕事を奪われないために、Excelの印刷ズレの微調整で抵抗を続けていたー
# @yumemizaka_2 そこは初めてばれました笑
# @yumemizaka_2 夢見坂さん、ありがとうございます
# 読んでいただけて嬉しいです！！
# @itengr_moyashi ありがとうございます！！
# めっちゃ置いてくださっている…！！
# RT @ke_ru_noyounamo: Excelの本、実はパワークエリ・ピボットの入門書ぐらいしか持っておらず、せっかくなので買ってみました。僕みたいに普段ググってその場しのぎで済ませてる人に良いかもしれない。
#
# 一番好きな関数ちゃんはSUMPRODUCTだけど、XLOOK…
# RT @ezokanzo: 【ご報告】
# 昨年に引き続き、今年も旭川で開催されます「北海道金魚すくい選手権大会」のポスター制作させていただきました！第10回という記念大会…姫蘭ちゃんの新規立ち絵も描かせていただきました🥳✨
# また旭川などでポスター発見されましたら、是非ご覧ください…
# @aikostar30 楽しんで頂けて良かったです！
# 初めて知った子もよろしくお願いします！
# @mamoru_furuya @IT_craftmanship 「うん。私もFさんもフルヤさんが嘘つきだなんて思っていないよ」
# RT @matudakta: 本当の会議は会議が終わってから始まる現象(笑)
# first_flg: False
# @mamoru_furuya 経理にいると、だいたい見えるので…どれだけやってもフリーザ様になれそうにないな、とか笑
# 書籍を送るのにクロネコの匿名配送にお世話になりました（紆余曲折はあった）
# プレゼント企画などに使われているようですね、便利〜
#
# https://t.co/Uf6tFLet4K
# @mamoru_furuya いつかなれるアテがあるんですか？？
# @johnchung1975 @MasazaneKunohe 書店チェックありがとうございます！
# この時期はExcel本たくさん出るようなので店員さんも忙しそうです！
# RT @matsbox: 筒井さんのExcelツイートや関数ちゃんたちの擬人化で、関数といえばSUMしか知らなかった私が「関数ちゃんに頼ってみようかな？」と思えたので、本当にありがたい存在です！
#
# 先日発売された筒井さんのExcelの書籍もめちゃくちゃとっつきやすくてオススメで…
# @aikostar30 aikoさん、ありがとうございます！
# お茶のお供に読んで頂けるとは嬉しいです！
# ←カイル君
#
# →Copilot https://t.co/hitV6VDZzt
# RT @Excel_design_Dr: Microsoft365の新関数。俺はお前たちにものすごく期待をしている！
#
# TEXTBEFORE
# 特定の文字の前の文字列を取り出す
#
# TEXTAFTER
# 特定の文字の後ろの文字列を取り出す
#
# TEXTSPLIT
# 特定の文字で文字列を…
# @hirachin22 ひらちんさん、ありがとうございます！
# ブログの関数ちゃんイラストを更新していきます
#
# #関数ちゃん https://t.co/dMpem0nxnV https://t.co/byPD0ZBuJp
# first_flg: False
# RT @Tsutsui0524: 関数ちゃんのLINEスタンプ作りました！
# 16個セットで120円です
#
# 今度はExcel関数擬人化ではなく、関数ちゃんです…！！
#
# #関数ちゃん #広告
# LINEスタンプ購入ページ
# https://t.co/RheZOIVPd6 https:…
# RT @DETCH23: Excelの教科書としてもうってつけだなって思う。
#
# 関数ちゃんと学ぶエクセル仕事術 実務で役立つExcel関数を擬人化したら？ - インプレスブックス https://t.co/Kl3TdSyN4D
# @ShiodaKayak CSV…Excelで…うっっ！！
# RT @ShiodaKayak: XLOOKUP #関数ちゃんファンアート #祝書籍化 #関数ちゃんと学ぶエクセル仕事術 https://t.co/ZXvbItpnRg
# @mikimomo_as アカウント作ったけど、複数アカウントとか器用なことできなかっただけというやつです…！
# 好きは人を惹きつける
#
# 私が以前より暦に興味を向けるようになったのは、松浦はこ先生の暦日擬人化がすごく楽しそうだからだと思います https://t.co/FIpe5SMmcE
# @ke_ru_noyounamo 100均の小麦粘土がわりと充実しています
# ただ、服についたりポロポロ散らかったのを掃除するのはちょっと大変です
# RT @Tsutsui0524: シート名を変更しても参照先が追従するINDIRECT関数式です
#
# FORMULATEXT関数が自セルを引数にできるので、
# 空のセルを参照する式を頭にくっつけてそこからシート名を取得します。
#
# [数式]
# =名前が変わるシート!A1&amp;INDIREC…
# @matudakta @blue201507 編集の方にも「Excel好きはガンダムが好き」と言って押しました笑
# @matsbox こいつ（この年）は俺が連れて行くよ的な感じ、しません！？
# 大晦日が待ちきれません！！
# first_flg: False
# @matsbox めくらずポイ（保存）その一年に最後まで付き添う感じがして尊みが増します！
# @matsbox そういえば、大晦日のひめくりカレンダー
# めくるのか、めくらないのか問題…とかないですか？笑
# きちっとめくるのか、めくらず閉じ具ごとポイするのか的な…
# @pippi_vba @matudakta 尚、いくつかの書店がレシピ本コーナーに並べてしまう模様
# @DETCH23 チュートリアル的なものが作れると楽しそうなんですけどね
# 聞かれた順に引数を渡せば答えてくれる、というのが関数ちゃんの初期イラストのコンセプトでした
# アシスタントっぽいですよね
# @ke_ru_noyounamo ねんど、ですかねえ…
# @matsbox ひめくりの厚さの違い、なんか良い絵ですね！！
# @matudakta @MasazaneKunohe 関数ちゅん、普通に気付かなかった笑
# いろんなトレーディングカードのデザインを眺めています
# こういうインプット？の時間、本当大事…
# @IT_craftmanship カチッ…
# @glucosamineZ @mikimomo_as 著者の欄を書くときに知ったのですが、ビジネス書は著者の肩書が大事というのがありますよね
# 士業、外資系金融、GAFA勤務…これらが漫画などでの賞にあたるイメージです
#
# ラノベだと著者説明は著者の人物像が主張しすぎないようにするらしいです
#
# こういう発見もあって面白かったです
# first_flg: False
# @IT_craftmanship マジで読まない稟議書に、会議の外でものを決める会議に本気で取り組むのがお仕事…！！
# @ymmox 伝わったの嬉しいです！笑
# 太公望と読者の温度差凄かったですよね！
# RT @Tsutsui0524: 映画の前にハートキャッチプリキュアの予習完了その2！
# キュアマリンが大人気なのはすごく分かる
#
# #ハトプリ #プリキュア #precure https://t.co/Nh1Yw0dABF
# RT @a03: ✧＼\ ハッピーサポーター /／✧
#
# 介護の錬金術師
#
# こんなんずるいやん https://t.co/S3sy73RCdu
# @DETCH23 でっちさん、ありがとうございます
# 刺さる人には刺さりそうな気はするのですが…！！
# これからどうなっているのやら！
# @ymmox 懐かしい王天君…！！
# 帽子取って、太公望とそっくりだろ？的なシーンでそれほどそっくりに思えなかった記憶が蘇りました
# @na_da513302 いやもう書店に並ぶこと自体が奇跡なので…！ありがたや〜
# @shimochan_dayo MATCHに怒られます
# クオリティはともかく、普段アナログで描かないのでレアものです笑
# @Bug1978 バグさんのExcelとの関係はかなり特殊な感じでしたよね
# いざ関数を使うと、すごい使いこなしをする印象です…！！
# お勧め頂けますとありがたいです！
# @siecov 炎上ではないことを願います…！笑
# first_flg: False
# ポップありがたいです…！！ https://t.co/Y08Y13S4Xs
# @mikimomo_as @kadukijob できるシリーズが試される時…！
# @lara_summer_mim Miさん、ありがとうございます！
# 擬人化自体は先人がいたのですが、継続したのは、たぶん初です
# 私もIFERROR好きです！
# @Bug1978 バグさんありがとうございます！！
# 嬉しい・・・！！
# @ManaitaBacon スマホでやったら超タイヘンでした
# 部下「議事録できました。ご確認お願いします。」
#
# 上司「どれどれ…あ、ここ会議後の雑談で変更になったから修正して」
#
# 部下「議事録では…？」
# @kadukijob 光希桃先生の知見は後世に語り継がれるべきですね
# RT @ManaitaBacon: Power Automate for desktopを使って
# 自動でチェックはずせた♪
#
# 楽ちん、楽ちん♪
# でも、ループ300回じゃ足りなかった～
#
# 最後はエラーで止まります^^;
#
# ALTに全部は入らなかったので、
# URLと、
# UI要素をテ…
# @glucosamineZ @mikimomo_as 今年はTwitterで知った人が3人も本を出すというので驚きました
# フォロワー2万程度では売り文句にもならないようです
# @KotorinChunChun 他人事なのに動悸が…
# first_flg: False
# @siecov ありがとうございます！
# 変な本をパソコンコーナーにねじ込んでやったぜと思っていたら、編集さんも同じように思っていたらしく、どうりでやりやすい訳だと思いました笑
# @MasazaneKunohe この人選が通ったの本当に良かったと思ってます笑
# 手に取って！という感じがしますよね！
# RT @Excel_design_Dr: 「知ってて当然」っていう世界観になってほしい！ https://t.co/7PSgEP7mUu
# RT @LukeSilvert: ・LEFT 関数の第一引数は文字列
# ・日付は数値
#
# という知識があるせいで、LEFT の第一引数に日付を指定するという発想が無意識に排除されていたことに驚いた。
#
# 型の概念を持つ前だったら、この考え方をする可能性はあるし、この結果を見て、「えっ…
# @blue201507 ROUNDまわりは複雑になった感じがしてます
# ブログの記事から切り取った部分が多く、過去の苦労が役立った感じがしました！
# @okinawa__noodle タナイ社長、ありがとうございます！
# 本棚で異質な存在になりそうです…笑
# @MasazaneKunohe くのへさん、ありがとうございます！！
# RT @impress_corp: ＼ 大好評につき期間延長 ／
#
# 『関数ちゃんと学ぶエクセル仕事術』
# まえがき～第1章の #無料公開 を3月31日まで延長することになりました！
# 多くの皆さまにご覧いただき、話題にしていただいたおかげです！
# ありがとうございます。
#
# ぜひ関数ち…
# @TETRA_IT あちこちからプロの方の指摘入りそうですもんね笑
# @apis_r でっか！笑
# たしかに、終焉を迎えるとアイコンとして使うのもおかしい感じがしてきますね
# first_flg: False
# @TETRA_IT フォロワー減るからですか？
# かけていきましょうよ、ふるいに（無責任）
# @apis_r 保存ボタンネタと同じですよね
# @Excel_xlsx おお！そうなのですね！
# 青りんごさんから見て、エクセルにとっての大事件でしたか？？
# @blue201507 共著ですので、内容は充実していると思います！！
# blue先生ありがとうございます！
# RT @blue201507: 関数ちゃん恐ろしすぎ😳。知らない関数の勉強にと思ってたけど、知ってる関数でも知らない小ネタが多いので勉強になる😊 https://t.co/tLLUOBvTVX
# やってみました https://t.co/peikIT6vAP
# @turkey_jp @mine__0 ひええ
# RT @Tsutsui0524: フォルダへのショートカットのプロパティを開いて、リンク先の先頭に「explorer 」（末尾スペース有り）を追加すると、ダブルクリック時に毎回新しいウインドウで開くようになる（さいきん知った） https://t.co/62z5K5Kxp7
# @narutonokaeru サービス名や社名って意外な思いが込められていて面白いのですよね
# @N_noir_7 結構わかってしまう…やばいですね笑
#
# 役職ついた時、毎月冷蔵庫買い換えられる！！って思ってました
# やばい
# first_flg: False
# RT @Tsutsui0524: インプレス様の書店向け情報紙「できるもん通信」に1ページ掲載頂きました！
# @narutonokaeru えっっ！？そういうことですか！？
# 引き出しいっぱいに袋詰めのシュークリームを敷き詰めていて、その中の一つを裏返すと要冷蔵と書いてあって、膝から崩れ落ちる
# という夢を見ました
#
# おはようございます
# @OfficeTAKU それ私も思ったことがありました笑
# 画像などない状態だと『ちゃんと学ぶ』本ですよね笑
# RT @Excel_design_Dr: これはマジなんだが、SUMIFS関数をマスターすると、とにかくExcelレベルが爆上がりするんよ。関数の構造だけじゃなくて、参照、条件式、データベース形式、データ型とかあらゆるExcelの基礎がSUMIFSに詰まってるわけ。言ってる意味…
# #関数ちゃん マンガ『見た目度外視』
#
# LEFTちゃんに日付から月を取ってきてもらおうとすると失敗するという話
#
# でも、4月だったらシリアル値の先頭4が返っているのに、月が返されたと勘違いしてしまう可能性があるのかと怖くなりました https://t.co/2JuoOepfLo
# ブログの方もイラスト更新したり色々やりたいことがある
# 楽しいなぁ〜
# @YUExcelMARU Excel「ささいな変化にもちゃんと気づいてくれるゅぇ。さんが気になる」
# @excelspeedup これが、はけた先生のいう『ちゅんちゅんする』ですよね
# @mom741852 @matudakta mowさん、ありがとうございます！
# 松田軽太さんに感謝せねばっ
# first_flg: False
# @usamiko うさみこさん、ありがとうございます！
# 知っている関数と、より親密になれることを願っています！！
# @RPA_Journey ありがとうございます！
# 楽しんで頂けたようで良かったです！
# 結構ネタを入れさせてもらえました笑
# @ivor_opn あいばさん、ありがとうございます！
#
# ブログの内容に比べて本は初歩的な内容になっているので、ご期待に応えられるかどうか…
# @toarutoa だらだらしてる場合じゃねえ！！
# @ezokanzo わかる！！
# @UFOnian 瞬間湯沸かし器の可能性出てきましたね
# @RPA_Journey 今すぐ送りたいくらいです
# ryokoさんありがとうございます！！
# 無料公開の期間が今日までになっていましたが、好評により月末まで延長となっています！
#
# そりゃ試し読みしてみないと相性も分からないですよね！笑
#
# 『関数ちゃんと学ぶエクセル仕事術』まえがき〜第1章 無料公開キャンペーン - インプレスブックス https://t.co/P76gU0FznU @impress_corpより
# @tone_kawaraya 瓦屋トネさん、ありがとうございます
# 親しみが持てるというのは、非常に嬉しい感想です！！
# RT @wafu_spaghetti: 明日よろしくお願いします！！
# first_flg: False
# @na_da513302 すごく嬉しい宣伝文句です！
# @blacklist_ryu そうか、学校指定とかになれば…
# @Skillup_VBA スキルアップさん、ありがとうございます！
# @hosaCapsaicin 補佐さんありがとうございます
# 結構ネタ入れさせてもらえて、打ち合わせ楽しかったです！！
# @blacklist_ryu りゅうりゅうさん、ありがとうございます！
# なんと素敵なお父様でしょう！！
# @siecov しいこふさん、ありがとうございます！
# 会計士でも外資系でもMBAでもないですが、何とか本を出せました
# 序盤、賑やかですよね笑
# ごちゃごちゃした業務フローをAIの力でなんとかするんじゃなくて、まずは業務フローの整理をしようよ…嫌だろうけど、きっと何かいいことあるよ…
# @kabanyasu KBにゃす先生、ありがとうございます！
# 楽しんで頂けると良いのですが…！！
# @s5ml 画面の端とかだともう無理ですし、OS側の動作が呼び出されたりしてお手上げなことも笑
# AIでExcel講師の仕事がなくなるかと言うとそうでもなくて、より『本来教えたかったこと』に注力できるようになるんじゃないかなぁと思う
# first_flg: False
# スマホでこの手の調整バーを見ると『まぁ1度目は動かせないだろう』と覚悟している https://t.co/8El2ZbQHT3
# @saboritami 私もSUMPRODUCTちゃん好きです！
# こないだ使う場面に遭遇して嬉しかったです笑
# すぐ顔に出る経理マン、あだ名が『感情奉行』
# RT @sugoi_kaizen: Excel講座を担当しております。
#
# 完全無料は怪しい…と仰ってる方もいらっしゃいましたがもう少し世のマーケティング成功事例を勉強されてはと思います。
# 「一生遊んで暮らせる」 https://t.co/y5T8dzHX11
# @toshi81350036 おねがいしまっせ〜
# RT @dekirumonn: できるもん通信2023年3月第56号
# #note にて公開！
#
# いま話題の #ChatGPT  の新刊紹介
# #OneNote の活用事例
# SNSで大反響の #関数ちゃん
# と話題がいっぱいだもん。
#
# 🔽こちらからご覧くださいだもん🔽
# https:…
# @ymmox 技術書展というのがあるのですね？！
# ちょっと聞いてみます！
# ありがとうございます！
# @yosatonet ゲームの攻略本コーナーに置く…？
# #これを言ってくるやつは信じるな
#
# 『俺が怒るのは10回我慢した上で表に出た1回だから』
# first_flg: False
# @furyutei 平置きではないときにIFERRORちゃんが正面きって主張するという構えです！笑
# RT @furyutei: #関数ちゃん 本、背表紙には私的イチオシのIFERRORちゃんもいます！（5人の中で表紙に出ている唯一のメガネっ娘） https://t.co/GWUri61CgO
# @turuya13 鶴屋さん、ありがとうございます！
# 取り扱いにはご注意ください！笑
# @OfficeTAKU Office TAKUさん、ありがとうございます！
# 1人でもExcel関数入力してくれる人が増えると嬉しいです！
# RT @OfficeTAKU: Excel の講座やってると関数に拒否感を示す方が少なからずいます。
# めんどうな計算やってくれるからめっちゃ便利なんだけど…
# そんな方におすすめ！
# @Tsutsui0524 さんの『関数ちゃんと学ぶエクセル仕事術』
#
# ちなみに私の推しは、NOWち…
# インプレス様の書店向け情報紙「できるもん通信」に1ページ掲載頂きました！ https://t.co/T1jjhvHHJT
# フォルダへのショートカットのプロパティを開いて、リンク先の先頭に「explorer 」（末尾スペース有り）を追加すると、ダブルクリック時に毎回新しいウインドウで開くようになる（さいきん知った） https://t.co/62z5K5Kxp7
# @taq_tak よく見るやつですね〜！
# @sugoi_kaizen なんちゃらエージェントとか、そういう名称ですかね？
# 分かりやすくてかっこいいの付けたいところですよね
# RT @apis_r: 実際に言われて『前のは？』と視線の圧で押し返した案件
# 更新データ来ても対応できるように作ったよっていう文言は彼の頭の中には残っていなかったようだ（再度そう言ってもﾃﾞﾓﾃﾞﾓﾀﾞｯﾃではあった）
# #鯰尾極先生のExcelのりぬる https://t.co…
# first_flg: False
# FLOOR関数とCEILING関数も紹介してて、どんな関数あるのかざっと知るには本当に良い本だと思いました https://t.co/cOWkFRkRpH
# @matudakta ブログでご紹介ありがとうございます！
# 関数ちゃんって何？って聞かれたらこのページ見てねって言うレベルです笑
#
# 本が出て一旦は落ち着きましたけど、機会があれば色々仕掛けていきたいですね
# 本当、ここからですよね〜
#
# YYEAR関数になっているところがありました！（読んだ証拠）
# RT @saitomoko: わーい！待ちに待ったKindle版関数ちゃん https://t.co/dOEcsfCk29
# @matudakta 松田軽太さんは嬉しいこと言ってくれて困りますね笑
# イラストレーターに依頼しても同じようにはできない、そう思いたいところではあります！
# RT @waenavi_jp: excelで現在の時刻が8：30より前だった場合、一日前の日付が表示される関数
#
# 8時半を引くだけですね。
# =NOW()-17/48
# RT @matudakta: 筒井さぁ～ん、ブログを書かせていただきました！　@Tsutsui0524
#
# はてなブログに投稿しました #はてなブログ　#関数ちゃん
# 『関数ちゃんがついに本になったよ！』　～関数ちゃんがExcel本の新たな地平を拓く理由～ - 松田軽太のブロぐる…
# @pD1epkuzfNKcluN たーーーーっさんありがとうございます！
# 本音が漏れてますよ〜！
# @vvqe1ji6kYe7e6p とざわさん、ありがとうございます！
# 競技Excelがきっかけですか！？
# 楽しんで頂けたら嬉しいです！！
# @Sagittarius8083 なるほど〜！！
# パソコンが普及することで出てくる問題（と言うほどのものでもないですが）もあるのが面白くて
# この二つも書き間違うことはないと思うんです
# @OElwLDyW1tHGhvq あなたはおとうさんのふようにはいっているのよ
# first_flg: False
# @Elwood_67 プロポーズかと笑
# @MasazaneKunohe @matudakta どうしましょう「あいうえお」を、「おえういあ」にする数式を作るストーリーで…いやいや
# RT @smskn: 関数ちゃんがいっぱい展示されてた😇
# 読むの楽しみ。 https://t.co/wnGCqW3aYj
# 「不要家族」という変換ミスのインパクトがシャレにならないので「扶養」は別の言葉に置き換えられないものだろうか？
# @biitarou こういうちょっとした押印欄などのための調整大変ですよね…！！
# @sugoi_kaizen 読書量…学生の頃から本はよく読んでいたんですか？
# RT @Tsutsui0524: 退屈なことはPythonができる人にやらせよう https://t.co/XKg51QnoXN
# Amazon売れ筋ランキング
# 表計算部門で現在２位！
# ありがとうございます～ https://t.co/FQfZ1I2Ub9 https://t.co/nzcPpmU4we
# @innovator_nao そうですね
# しかし、感覚として550億円という数字にびっくりする気持ちは分かります笑
# @Hiro_officewrkr @TAKAMAN02345158 たしかに、その筋っぽいですね
# first_flg: False
# RT @Tsutsui0524: 関数ちゃんマンガ『アレ』
#
# 引数と言ってる人をリアルで見ると、おおっ…てなります
# 名前を覚えると、知識が増えた感じがします
#
# 漫画もぼちぼち増やしていきます！
#
# #関数ちゃん
# #漫画が読めるハッシュタグ https://t.co/1W5Zxi…
# @innovator_nao GPIFの運用資産189兆9,362億円(2022年度第3四半期末現在)
# とあるので、550億円は0.029％
# 300万円運用している人の869円に相当と考えると、そういうこともあるかなぁって感じですね
# RT @Tsutsui0524: 半分の時間で仕事が終わる人に「けしからん」と倍の仕事を振って、その人がいなくなる時にパンクする光景…何度見たことか
# @N_noir_7 子供のことはそれはそれはおとなしい良い子だったので、なんとあと8000回は残していますね
# @N_noir_7 これ！
#
# https://t.co/3KQ1xMsGrd
# @sugoi_kaizen 吉田先生の文章力は、どこで培ったものなのでしょうか？
# セル範囲をコピー、図として貼り付け
#
# 書類の押印欄を作るとき、セル結合したり列幅調整するより、図として貼り付けが楽～ https://t.co/f5db7I4ESf
# @smskn らむおさん、ありがとうございます！！
# らむおさんに読んで頂けるとは感慨深いですね
# これからも宜しくお願いします！
# @qpgmr516 社畜度というパラメーターで調整できるようです！
#
# https://t.co/KHtxvOIxOv
# @qpgmr516 それはもうRelaxTools addinさんがやっているので…！笑
# first_flg: False
# 動画のように、目次をクリックすると表示が変わるシートを作る方法のブログ記事です！
#
# 『ウインドウ枠の固定』と『HYPERLINK関数』を使います！
# https://t.co/Y7WWQJvyQC https://t.co/yr63B9badF
# @mine__0 いつもの！ありがとうございます！
# RT @Tsutsui0524: Amazon総合で500位内に入りました！！
# 文書作成カテゴリで1位を頂いています！
#
# …ん？文書作成？Excelで…？ウッ！！ https://t.co/6kqWVHlV8y
# Amazon総合で500位内に入りました！！
# 文書作成カテゴリで1位を頂いています！
#
# …ん？文書作成？Excelで…？ウッ！！ https://t.co/6kqWVHlV8y
# @nitoukinnosuke コスチュームも可愛いかっこいい…！！
# RT @Kuroi_CPA: 「関数ちゃんと学ぶエクセル仕事術」ゲット！
#
# 経理の仕事で絶対使う関数たちを紹介してくれており、知らなかった便利な機能や関数もあり勉強にもなった！
#
# また、ところどころにある小ネタが実務で共感するものが多い。特にSUMIFとSUMIFSのコラムは共…
# @umaumaBEER 色合いが綺麗でかわいいです！！
# RT @excelspeedup: エクセルのすべての作業はSUMIFS関数を使うための下準備。
# @libon0412 @matudakta みなみんさん、ありがとうございます！
# @nixuko @matudakta @NreviewTorito 本屋さんで見るとIFERRORちゃんを全力で応援したくなります笑
# first_flg: False
# RT @emeen231: 好き
# @0612Xlookup3 @matudakta こないだスクーで拡張子xlsがボロクソ言われてて泣きそうになりました
# @Excel_xlsx 元に戻すが無くなったって大騒ぎでしたからねえ…
# RT @ayuneo: この画像って未だに見かけるけど、作ったの私なんだよね。当時思いの外あちこちで貼られちゃっ反省してすぐ消したんだ。若気の至りだったなと…
# 私はこれしか作ってないけど第5話まで出てるって何？ https://t.co/hSMIX76Vjq
# @1RRhcSB6HSUu9hF @zeimu_nagoya 小林先生「チッ、また壊れたか…軟弱なマウスだ(新品のマウスを開封しながら)」
# RT @Excel_design_Dr: うおー！2冊目！😂
#
# 『人生を変える　Excelの神スキル』
# 💮4/28（金）発売！
# Excelができるは神スキル！元Excel初心者だった私が書いた、人生を劇的に好転させるExcel本。Excelできる人は買わないで下さいね😅Amaz…
# RT @matudakta: #関数ちゃん 本の強みは、著者自身がExcelを愛し、Excelに愛されてるという点だろう。
#
# Excelを知らないイラストレーターに擬人化イラストをデザインさせても、おそらく萌え萌えした無難なキャラクターになるだけだ。
#
# しかし筒井さんは心底Ex…
# @hikari9629 MATCH優秀ですよね〜！
# Ctrl + S
# 上書き保存
#
# 複数シート編集してしまった後で大惨事になることもありますけど、やっぱり保存は大事！！
# #Excel https://t.co/LR2tlKbRkv
# @ksgiksg おお、よい出会い！！
# first_flg: False
# @nixuko にぅ…にぅさん、ありがとうございます！
# 筒井駅周辺、本屋ないんですね…なんだか興味出てきました笑
# @ExcelVBANgmg masaさんありがとうございます！
# この売り場は感動します！！
# @nixuko @matudakta カバー裏に期待されても何もありませんよ笑
# RT @ShiodaKayak: 一気に読めました。めっちゃいい本！
# 役に立たない情報が一切ないのすごい！
# あと漫画・アニメネタが無尽蔵に出てきてずっと楽しいw
# 学習コスト全然感じないまま最後までいってしまいます。
# 定番関数しっかりなのも素敵。からの終盤の展開が最高！
# エンドロ…
# @derAnfang2021 レイさん、布教活動ありがとうございます笑
# @ShiodaKayak しおださん、ありがとうございます！
# ネタを仕込むために、ネタ勉強用の本を買いました
# 嬉しい…これはうれしいです！！
# @ShiodaKayak しおださんっ！！
# @celaeno4 良いですね！！
# @sugoi_kaizen そんなセリフを吐く悪者をケンシロウがエクセル百烈拳（関数などのテクニック）で倒すという構成です！！笑
# @hiro_izushi ひろさん、ありがとうございます！！
# Excel愛、関数愛です！！
# first_flg: False
# @zeimu_nagoya 私は職場と家で同じマウス使い回してるのですが、時々会社にレシーバー忘れて帰ることがあります
# なるほど、レシーバーだけもう一つ用意すれば解決するんですね…！
# 資金繰り表Excelには、様々な思想とそれを実現する工夫があって興味深いですね！
# 毎月発生分は一括登録…ナルホド https://t.co/X6CySFoDu4
# @ksgiksg どこでその力を手に入れた？？
# @UFOnian あと43分！
# @KotorinChunChun 極めて自然な流れですね…自然だ…
# @maeK_School まえかわさん、ありがとうございます！
# 日付の3人娘は姉妹ではないことになっています！
# @matudakta 平積みでなくても、背表紙はIFERRORちゃんがバッチリ守っているという布陣です！！笑
# @Seth_Aug Sethさん、ありがとうございます！
# 楽しんでいただけて嬉しいです！！
# @keito_oz ああ…なるほど笑
# @kadukijob 華月さんありがとうございます！
# 布教…思想を広めてくださりありがとうございます！
# first_flg: False
# @NuclearFlower 私はユニクロでTシャツにしましたよ〜！
# @matudakta 選抜するの楽しかったです！笑
# @keito_oz これ、何だったんです？？
# @usamiko MONTHとRIGHTなら…
# @MasazaneKunohe 夢の印税生活や〜！
# @XNY1eyogmR8ki6h コピペさんありがとうございます！
# 置いて下さっている本屋さんで良かったです…！！
# @pippi_vba ピッピさん、ありがとうございます！
# ちっちゃいリフト可愛い…！！
# 超巨大な本に見えます笑
# @maxima_hikky susukiさんありがとうございます！
# トンカツのお供にぜひ！！
# @usamiko うさみこさん、ありがとうございます！
# 期待値が高いような…！！
# @akizyu1 北斗の拳は私は未履修でしたけど楽しめました笑
# 簡単にキャラの相関図くらいは知っておいた方が楽しめそうでした
# first_flg: False
# @osatoexcel 届きましたか〜！
# おさ先生のスピードandパワーには敵う気がしませんが、頑張ります！
# ありがとうございます！
# @Kuroi_CPA 白井先生、ありがとうございます！
# タイトルは色々勉強して考えました！笑
# 元ネタが分からなくても、元々が名言なので良いこと言ってる風になるかなぁと…
# 半分の時間で仕事が終わる人に「けしからん」と倍の仕事を振って、その人がいなくなる時にパンクする光景…何度見たことか
# 関数ちゃんマンガ『アレ』
#
# 引数と言ってる人をリアルで見ると、おおっ…てなります
# 名前を覚えると、知識が増えた感じがします
#
# 漫画もぼちぼち増やしていきます！
#
# #関数ちゃん
# #漫画が読めるハッシュタグ https://t.co/1W5ZxipV0S
# @matsbox 流石の知見でございます…！！
# 一つ賢くなりました
#
# Excelは日本語怪しいとこあるので翻訳ミスっているという可能性も…
# @saitoo_3 少なくとも怒るのは違いますかねえ
# @tequila_gyosho テキーラさんありがとうございます！
# 楽しんで頂けると幸いです！
# @teruhata 椅子に座っている方に怪しまれないようにして下さいね笑
# めちゃくちゃ面白かったです！
#
# ・紹介している関数が多い
# ・重複しない順位を作る数式を扱っている
#
# ツボ：
# 「過労死兆星」
# 「キーボードを突く」
# 「電卓より優れた計算方法など存在しねえ！」
#
# #広告
# 世紀末救世主伝説 エクセル関数北斗百列拳 https://t.co/89q9i0aJG1
# 定時で帰れるかどうかは、覚えたショートカットキーの数ではなく、職場環境でほぼ決まる https://t.co/BG0vInfF5a
# first_flg: False
# A「5万円くらいでおすすめのパソコン教えて欲しい」
#
# B「このパソコンがいいよ」
#
# A「ありがとう」
#
# B「5万円ちょうだい」
# ゾロ目！ https://t.co/I3JaVQTi8T
# @chanryo_eff 電子書籍は後日発売される予定です！
# ちゃんりょう先生、ありがとうございます！
# @wayou001 最寄りの本屋に無いのはちょっと寂しかったりします！
# @ymmox 山本ゆうか先生、ありがとうございます！！
# ちょっと難しい内容のところですが、ROUND姉妹と一緒に読み進めて貰えたらと思います！！
# @qua_pas_rec つるぴか⭐️ヒゲ丸さん、ありがとうございます！
# 関数の歌楽しみにしています！！
# @wayou001 わようさん、ありがとうございます！
# 私の地元には1冊も…
# @matsbox 祝日と祭日は、原稿書くときにブレまくって迷惑かけてました…
# 一応、Excelの入力補助では祭日表記ですね https://t.co/m8ejGY3pIC
# RT @nyamadampersand: とある会社の資金繰り表はこんな感じで作っています。
# 実績はもちろん自動集計です。 https://t.co/3qvEWSc8Po
# @Spumo そ、そっちですか～！なるほどォ！
# first_flg: False
# @derAnfang2021 レイさんありがとうございます！！
# 良い置き方して貰ってますね…！ありがたや～～！
# @nyamadampersand @sugoi_kaizen ところどころ共通点があって、少し安心しています…！
# 資金繰り表はエクセル大活躍って感じですよね
#
# 各々の最強の資金繰り表、ロマンがあります！
# @NETKEYCOM @KinoShinjuku 冊数もこんなにたくさん…！！
# ありがとうございます！！
#
# #紀伊國屋新宿本店
# @KinoShinjuku
# @NETKEYCOM @KinoShinjuku きーちゃんさん、ありがとうございます！
# 新刊の表示、ありがたや…！！
# RT @NETKEYCOM: すべてExcel関連の書籍...
#
# 　この中から目的の一冊を見つけるのは本当に大変で、新宿本店5階の店員さんには感謝しかない🙇🏻‍♂️
#
# #紀伊國屋新宿本店
# @KinoShinjuku https://t.co/BIgHz7BJKi
# ちょっと楽になるリボンの操作
#
# ・マウスホイールのスクロールでタブ切替
# ・タブのダブルクリックで表示・非表示の切替
#
# 画面共有中にダブルクリックでリボンを非表示にしたら「どうやったの！？」って聞かれました
# #Excel https://t.co/2ISmrSh3dT
# @sgtkrr 1900/1/1から起算して45000日目と言うと、実は44999日目と返されるTwitterは怖いところ…
# RT @Tsutsui0524: #第2回Excel関数天下一武道会
#
# こんなに勝利の似合う関数は他にないかもしれない…！
# 改めて、VLOOKUPおめでとう〜！
# (ちゃんとカラーでお祝いしたかった) https://t.co/CpmCv2q5mC
# @sgtkrr それが、存在しない日付というのがあってですね…笑
#
# https://t.co/LctOJWcFzz
# RT @alfistakeshi: 以前「アニメ作品のキャラ推しはない」と呟いたことがあるが訂正！『機動戦士ガンダム』フラウ・ボウと『ハートキャッチプリキュア』キュアマリンは好きwフラウは小学生の時の理想の女性だった。基本明るい女性が好きなんだなぁと。来海えりかはあの屈託のなさ…
# first_flg: False
# Teams「チャットでEnterキー押したら送信されたって文句言う奴らはそもそも、」
#
# Teams「ちがう。ちがうから。」
# @alfistakeshi ポーズ、表情、マリンらしくて良いです…！！
# @alfistakeshi 岡本健志先生のキュアマリンが見られるとは…！！
# @toshi81350036 なんの指示もしてないのに関数ちゃんと言い出してびっくりしました笑
# @toshi81350036 営業もありがとうございます笑
#
# 例文はbingさん作の小説であります
# @blue201507 blue先生ありがとうございます…！！
# @Sagittarius8083 今日は漫画を1点アップ予定です…！！
# @MasazaneKunohe イイ！！
# @OElwLDyW1tHGhvq 先生なんて呼ばれるようなアカウントではないですよ…本にも色々抜けがありますしね…
# @VBA07529852 おつかれさまです…！
# first_flg: False
# @matsbox 松浦はこ先生ありがとうございます！
# 日付とか祝日のあたりを考える時は先生のことが頭をよぎっておりました…笑
# RT @Tsutsui0524: とうとう本日発売です
# インプレス様に頂いたMARUZEN&amp;ジュンク堂書店梅田店の様子
# すごい見に行きたい…！！ https://t.co/tAQcLhf4zs
# PROPERでできることをUPPERとLEFTと…ってネストでやろうとしたことがある私には刺さりますねえ https://t.co/UZP18SmJrL
# RT @Tsutsui0524: NOW関数が2023年3月15日 0:00をお知らせします。
# ちなみに本日のシリアル値は「45000」です。
#
# エクセル講師の皆様におかれましては、キリが良いので動揺してしまわぬよう、お気をつけ下さいませ。
#
# #関数ちゃん https://t.…
# @okinawa__noodle @IT_craftmanship 天才…！
# @okinawa__noodle タナイさんのお役に立てるかどうか…！！
# ありがとうございます！
# @ke_ru_noyounamo けーるさん、ありがとうございます！
# 私もSUMPRODUCT推しで、VLOOKUPを脅かすXLOOKUPには冷ややかだったのですが、付き合ってみると優秀で良い子なので揺らいでいます
# @ke_ru_noyounamo 描き直しはしてますよ〜！
# @mikimomo_as そうなんですよ…
# そのほかにも色々出てきてます…
# @sugoi_kaizen アジアにある協力企業で、社長が急に生産設備の購入を決めてくるので資金繰りが苦しいと相談されたことがあります笑
# ドンブリ勘定、多いんですね〜！
# first_flg: False
# @IT_craftmanship 歯茎が歯の土台なのか、歯が歯茎を纏っているのか、そのあたりは見解が分かれそうですね…
# 歯科医の友人に聞いてみようと思います
# @na_da513302 na?さん、ありがとうございます
# なんだか感慨深いです！
# @ShiodaKayak 監査部門の指摘に回答するのはしんどそうですね〜
# NOW関数が2023年3月15日 0:00をお知らせします。
# ちなみに本日のシリアル値は「45000」です。
#
# エクセル講師の皆様におかれましては、キリが良いので動揺してしまわぬよう、お気をつけ下さいませ。
#
# #関数ちゃん https://t.co/lCebDfSBSF
# @sugoi_kaizen 国を救うとは…資金繰りに問題をかかえる組織を多く目にしてらっしゃるとか、そういうことでしょうか？
# @IT_craftmanship 結構お見舞いしてますね、歯茎
# みんな歯のことばかり気にして、歯茎を蔑ろにし過ぎなんですよ
# だから、私が思い出させて差し上げてるんです、歯茎を
# @sugoi_kaizen さすが目のつけどころが…
# Excelで資金繰り表作るというテーマでも盛り上がれそうです
#
# https://t.co/u1ebn5QXn8
# @mikimomo_as 私はフィードバックしたいです！
# （語らいたい）
# @moripro3 もりさん、ありがとうございます！
#
# イラストはそりゃもう頑張りましたけど、カバーデザインをデザイナーさんがばっちり仕上げてくれたのでお気に入りの表紙になりました！
# @itengr_moyashi クセが強いので慎重にご検討ください！笑
# first_flg: False
# @mikimomo_as 私は送ってもらったら出版社の方にも共有したいと思います
# で、私個人としてはできるだけご意見に対してフィードバックはしたいと思います
# （そこは〇〇な事情があったんです的な…）
# @hakoniwagadget はこにわガジェットさん、ありがとうございます
# そうですね、書き切った時は本当に達成感ありました
# 出版社様のサポートもかなり心強かったですが、それでもなかなか…！
# @Koh_Iwaki そこは弱点ですよね笑
# そのうち電子版も出ます
# ぜひご検討を笑
# @glayraven れいぶんさん、ありがとうございます！
# 会社に思想を広めてください笑
# @mikimomo_as そうですか？
# 読める範囲の文で、私もそこ引っかかってた！というのがあったので、すごく考えて頂けたんだな〜と思いました！
#
# でも確かに、今受け止めるのは危ないかもしれませんね笑
# @okinawa__noodle 営業力に驚きました…！
# @yamato_1413 やまとさん、ありがとうございます！
# 楽しんでもらえると良いのですが…！
# @_reime reimeさんありがとうございます！
# @ShiodaKayak うんちうんち！
# @RelaxTools ありがとうございます！
# first_flg: False
# @kotlinhighway ありがとうございます！
# @jon_vba_chopper ジョンさん、ありがとうございます！
# 関数が親しみやすくなってくれると嬉しいです！
# @kazu_shindo カズヒコーキさん、ありがとうございます！
# 少しずつ読み進めていただければと思います…！
# @yoyoyoshidada 吉田洋さん、ありがとうございます！
# 最新の関数は結構便利だと思います！
# @excel_pc 信金さんありがとうございます
# そわそわします…！！
# @MmRaiel raiel_mmさん、ありがとうございます
# 楽しんでいただけると幸いです！
# @LoverExcel 通常のコーナーはちょっと分かりにくい感じでしたね…！
# @actiolic 大林 河さん、ありがとうございます！
# @KotorinChunChun ちゅんさん、ありがとうございます！
# 緊張しますね〜！
# @mikimomo_as とりあえず著者にぶつけてみるというのは…
# first_flg: False
# RT @glucosamineZ: 3/26発売の新著はExcelで行う「前処理」に特化した本です。
# Excelは集計/分析が得意領域ですが、元データが散らばっていたり、不備があったりすると、肝心の集計/分析に入るまでに時間と労力が相当かかるもの。
# この解決策がほしい方、Exc…
# @fukarakaru ふさん、ありがとうございます！
# ベクターイラストの先生にお買い求め頂けて感無量です！
# @furyutei 風柳先生、ありがとうございます！！
# 入門なんてとんでもない話ですよ…
# @saboritami 池袋OLさん、ありがとうございます！
# 隣の本、私も持ってますけど3冊積んだだけで高さが凄いですね笑
# @wakamekiss @keitai_kai リツイートはできないですが、関数ちゃんフォルダに保存完了！！
# 髪の毛フワフワの可愛いVLOOKUPちゃん確保しました！
# @LoverExcel ありがとうございます！！
# 一冊減ってるのはKouさんが…！？
# RT @LoverExcel: @Tsutsui0524 さんの著書を無事に購入！
# コンピューター関連の書籍を見に来た人全員にアピールしてる。 https://t.co/fRjnbJPg2T
# @my_kirakira しゅんさん、ありがとうございます！
# 楽しんでいただけると幸いです！！
# @Hiro_officewrkr おせっかいと紙一重的な意見も、わかります笑
# @Atussy74049877 Atussyさん、ありがとうございます！
# 関数ちゃん、お役に立てると良いのですが…！！
# first_flg: False
# @radames1001 ラダメスさん、ありがとうございます！
# チェックお願いします…！笑
# @actiolic 絶対無かったのに、後から生えてますね、うん！！笑
# スピルあると、Excelのゲーム感が増す感じがします https://t.co/UTwZefsZRQ
# @asakotofuji 元気があって良いです！
# 書店見てきた…あった…
# ポップ付いとった…
# RT @Marina_fumetti: 私は私の絵柄大好き!!って感じではないんですが（こうなりてぇ〜とか、この人が描いてくれたら私描かなくていいなとも思うし）、へ〜、いい感じに描けてるじゃないと思うときもあるし、自分の絵からしか摂取できない栄養素があるんですよ…。
# RT @Kuroi_CPA: ありがとうございます！
# あれは自信作です💪
# @saitoo_3 はぐき
# @yosatonet ありがとうございます！！
# レビューは宝ですね…！
# @nixuko チャンスがあればサイン…ぜひ！
# first_flg: False
# @ksgiksg スピスピ！！
# 書籍をご購入いただいた皆様へ
#
# 現時点で2点、誤記が判明しています
# お詫びと訂正をご確認いただきますようお願い申し上げます
#
# あと6章扉イラストの虫眼鏡が欠けてしまいました
# 申し訳ございません
#
# 関数ちゃんと学ぶエクセル仕事術 https://t.co/EuCkBVDzQW… https://t.co/KPq4jL9ZFR https://t.co/XSR0TV2Gvx
# @yosatonet 佐藤先生っ…！！
# もう、なんと言えば良いのか…ありがとうございます
# RT @Kuroi_CPA: おめでとうございます🎉
# 本屋の一部をジャックするのいいですね！
# 憧れます😍
# @toshi81350036 としじさん、あざます！
# @AquiloPhi なるほど笑
# @rochcpa ろっち先生ありがとうございます！
# 関数ちゃんは初登場時にイラストが入るのですが、そのページを展開されている感じです！
# @keiriyume0314 おめでとうございます！
# RT @impress_corp: #エクセル のこと、これならわかる！
#
# 『関数ちゃんと学ぶエクセル仕事術 実務で役立つExcel関数を擬人化したら？』
# 3月14日発売です。
#
# #擬人化
# https://t.co/DWnhfVbIDL
# RT @toshi81350036: #Excelクイズ #VBAチャレンジ #PowerShellとかでもいいよ
# 長文が与えられます。1行で１ツイート制限のかかる長さにはならないもので構成されています。
# １ツイートに収まる範囲内でできるだけ多くの文字数になるようにうまく分割…
# first_flg: False
# @keiri_IS この記事です！
#
# https://t.co/sWAV2kKQOW
# @keiri_IS 経理部ISさん、ありがとうございます！
# 会計人コースのExcel記事、要点が絞ってあって、勉強になりましたし面白かったです！
# @ponzu_works ぽんず先生、いつもツイート拝見しております！
# ありがとうございます！！
# @s5ml うんうん、え？
# って感じですよね笑
# @johnchung1975 ありがとうございます！
# いやいや、注文して置いてくださるだけで奇跡ですからっ！
# @toshi81350036 このひと35億の人じゃないんですか？？
# @B_g_saiton 長野のやつですね！
# 美味しそうです…！！
# @mikimomo_as サイン会だなんてとんでもない…！
# SIGN関数もいつか擬人化したいです！
# @mikimomo_as ご意見伺いたいです…！！
# 関数ちゃんの活動はまだまだ続いていきますからね、試行錯誤しながら進んでゆきたいです！
# とうとう本日発売です
# インプレス様に頂いたMARUZEN&amp;ジュンク堂書店梅田店の様子
# すごい見に行きたい…！！ https://t.co/tAQcLhf4zs https://t.co/nzcPpmU4we
# first_flg: False
# @celaeno4 ありがとうございます！
# シノさんメガネですしね！笑
# @hosaCapsaicin 激戦区の表計算カテゴリーではありませんが、ちょっとはずれたところで1位を頂きました
# ありがたいです！！
# RT @matsbox: 🗓暦の擬人化　ホワイトデー編
#
# #暦の擬人化 #拝啓暦の上から https://t.co/kW1OauxYBx
# @apis_r わ！あぴ先生ありがとうございます！
# 私も知らないところは勉強しつつ原稿書いてました笑
# @actiolic わー！ありがとうございます！！
# RT @fs_jobchange: あるある、、、っ共感しながら
# 最後にこんな大きなセル結合があったよで吹いた笑笑
# @Kuroi_CPA この本、一番知りたいことが載っていそうな予感です！！
# @Hiro_officewrkr おお〜っ！さすが都会！！
# @kyuruz69545945 ただものじゃない
# RT @seisho_h: 共感しかなくてワロタ
# 特に最後のやつ、対応をよくやる…(ファイルサーバー管理者)
# first_flg: False
# ネット上にchatGPTの情報が溢れて、それを元に学習したchatGPTが「私はこうなんだ」と決めつけて自分の可能性に蓋をしてしまうまでいけばシンギュラリティ
# @yosatonet SAM関数…
# RT @Tsutsui0524: Excelの機能にセル結合ってあるやろ？
# あれ、ほんまはセル分割解除なんや
#
# 昼夜問わずセル分割してくれてる人たちのおかげで、私たちはExcelを便利に使えるんやで～
#
# #うそやでー https://t.co/9WtrHI0D8R
# @Monyons @mikahosi 地味に使う言葉との重複は怖いですよね
# 社員A「「とせき」の変換候補に「戸籍」が出ないからユーザー辞書登録した」
#
# 社員B「おおっ、効率化～」
# @mikimomo_as ありがとうございます…！！
# すっごい緊張します！！
# @Koh_Iwaki Excelの動画でxlsがめちゃくちゃ非難されてて、すごく辛い気持ちになったのを思い出しました笑
# RT @DemodoriGatsuo: 届きました！
# さっと目を通して予想以上に実務に役立ちそうなガチ本です！
#
# ホントに筒井さん凄い…尊敬します！
#
# 「関数ちゃんと学ぶエクセル仕事術」
# @Tsutsui0524 https://t.co/t3HWk227HC
# @turuya13 以前も挙げてもらっていました
# ありがたや〜！
# RT @mahusukaya: ノーモアセル結合(#･∀･)
# first_flg: False
# RT @masashikaikei: 最近Excel力が半端ない先輩の調書を見たんですが、発想力がやばいです
#
# やっていることは簡単ですが、そんな組み合わせ方があるのかといつも驚かされます
#
# Excelは難しい関数やコードの暗記よりも、「基礎」をうまく組み合わせる「発想力」の方…
# RT @pc_watch: 【本日のできるネット】「関数ちゃんと学ぶエクセル仕事術」まえがき～第1章を先行無料公開。17日まで https://t.co/CqyJ21ug0o https://t.co/MnVOv2MrVX
# @alice_book @impress_corp 目次読んで下さり、ありがとうございます！
# @wachi_yukkuri つまり、ここを掘って説明すればわちょんさんが公式
# @KK80979809 わらいましたｗ
# @MasazaneKunohe 私もさっきTLに出てきて笑いましたｗ
# @kotlinhighway 楽天早いですね…！！緊張します…！！
# RT @matudakta: 【マチルダさんにExcelを教えてもらう約束をしたアムロの巻】
#
# 「マチルダさんは総務課なのに、どうしてExcelの使い方を教えてくれてるんですか？」 https://t.co/PoONvlBnHx
# @DemodoriGatsuo 出戻りガツオさん、ありがとうございます！！
# 私はガツオさんのアグレッシブなところを尊敬しています
# 楽しんで頂けると幸いです！！
# RT @66enihcam99: 「私が開いてるから開けない…？」が好き。
# 嫌いだけど好き。
# first_flg: False
# 『Ctrl + .(ピリオド)』で選択範囲の四隅を移動
# 『Shift + 方向キー』で選択範囲を修正
#
# 四隅の移動は、選択範囲が端まで選択できているか確認するのに使ってましたが、アクティブセルが四隅を移動するので選択範囲の修正にも使えますね https://t.co/A0m2mTVJpM
# @toshi81350036 こうでしょうか？ https://t.co/pIkUONGijN
# @toarutoa こちらこそ、フォロー頂きありがとうございます！
# とあるんさんの他のツイートを拝見してめちゃくちゃ笑ったので、心の栄養補給のためフォローさせて頂きました！
# フリー素材っぽい人物のかけあいネタ最高です…！笑
#
# もしExcel学習の際に関数擬人化を思い出して頂けたら幸いです！！
# RT @Tsutsui0524: #関数ちゃん の本にベストセラーのリボン（？）が付きました！
# ありがとうございます！ https://t.co/cq8p5en6Ok
# @toshi81350036 これ凄いですね…便利そうなので使ってみたいのですが、
# 若干文章が消えるのは改行が悪さしているっぽいです…？？ https://t.co/xar0HCw4Hy
# @pippi_vba @shimochan_dayo @kadukijob @yosatonet みんなで作った本だと思っています！！
# @apis_r 本が続々と届いたりしているみたいで、そわそわしています…！！
# @IT_craftmanship &gt;強烈な我の強さ
#
# この回答見るとそこまで我が強く感じないのですが…！？
# RT @Excel_design_Dr: 総務省のわかってる人「やばい！日本人みんなExcelデータがめちゃくちゃだから効率悪すぎ！てか省庁の統計データもヤバすぎ！ルール作ったから、これ見てこの通りやれ！！」
#
# っていう神資料がこちら👇
#
# 全国民に配るべき！総務省が示した「デー…
# @yosatonet あ、なるほど…
# ネストというわけではなく、ミッションに協力して取り組むみたいな感じですね！
# これは相当知見がないと量を用意できそうにないですね…
# first_flg: False
# @yosatonet このあたり、神髄先生のサイトで勉強しました
# これ、本当納得いかないですよ…笑
# @yosatonet いえ、佐藤先生のご指摘もっともだと思います
# 言ってみれば配列数式も特別なものではないわけですし…
# なんなら参照だけでもスピルってできましたよね
# 表現は難しいですが、納得できる表現にはしたかったという思いです
# @yosatonet なるほど、たしかに仰る通りですね
# SUMもスピル対応版だとSUMPRODUCT的に使えますしね
# スピル登場後に実装された関数をスピル対応関数というイメージが付いてしまっていました
#
# 編集さんと情報共有させてもらいます
# 佐藤先生、教えて下さってありがとうございます！！
# @yosatonet LEFTにFINDの結果を渡すみたいな下りをストーリーっぽく作ればネストの解説本みたいなのもできそうですよね
#
# ただ、ネストしようとするとMIDとかいなくて困る子が結構いるので、今後は着実にキャラクター増やすのも大事だなと考えています！
# @yosatonet 先生、ここ質問なのですが
# XLOOKUPはスピル対応ではないですか？？
# RT @Tsutsui0524: あと２日…！！
# 早い書店で並んでいる可能性があるらしい…
#
# #関数ちゃん https://t.co/aNymBHS8dY
# @saitoo_3 投げやすそうではある！
# @ShiodaKayak わー、ありがとうございます！
# この見切れてる感じも、なんかISERRORちゃんのイメージ通り…凄いです
# お宝フォルダに収納！
# RT @ShiodaKayak: あと2日ですね〜📗　#ISEROR #関数ちゃんファンアート #関数ちゃんと学ぶエクセル仕事術 https://t.co/EV11uTlMCo
# @toarutoa そんな大したものでは無いです…！！
# Excel関数はSUMIFと言ったアルファベットの列と機能しかないですから、ここから擬人化という発想はあまり出ないのかなと思います
#
# 擬人化文化、面白いですよね！
# first_flg: False
# Ctrlキー起点のきほんショートカット
#
# まずCtrlキーを押して、押したままもう一つのキーを押します
#
# Ctrlキーは単独では何も起きないので、安心して押してくださいね https://t.co/xUaOYVN6Xd
# @apis_r あぴ先生おめでとうございます！！
# RT @Tsutsui0524: Excelの必須ハンドサイン https://t.co/TkpZWV7hn9
# RT @akiran62: わたしが開いてるから開けないが最強すぎる
# @yosatonet 薄い本のノリなのは否めないですね…笑
# 制作の打ち合わせも、ひたすら楽しかったです
# RT @toarutoa: もう擬人化されてないもの無い説 https://t.co/uWp38iCJhe
# @rememberIT5055 表紙の方は猫要素入っていないのですが、もし機会があればよろしくお願いします！
# @otakara0103 @yosatonet お二人ともありがとうございます
# @yosatonet 佐藤先生からのレビュー、ありがたいです！
# 次回があれば反省を活かしたいです！
# @toarutoa Excel関数擬人化してます
# 取り上げて頂き、ありがとうございます！
# first_flg: False
# レビュー隅々まで読ませていただきます
# ありがとうございます https://t.co/ve2cSKzMfd
# @hashikko845 ありがとうございます、はっしーさん！
# 緊張しますね〜
# @hpeo_jp ありがとうございます！！
# またお前を使う時が来るとはな…「飲み会傾斜精算.xls」
# RT @yosatonet: 筒井さん届きましたよ
# 楽天ブックスから
# @Tsutsui0524 https://t.co/9YEbwE6Fv4
# @Koi_1030 教えてくださってありがとうございます！
# 都会で並んでいるの、見たかったです！！
# （当方、田舎につき）
# あと２日…！！
# 早い書店で並んでいる可能性があるらしい…
#
# #関数ちゃん https://t.co/aNymBHS8dY https://t.co/nzcPpmTwGG
# @MasazaneKunohe か、かっこいいぃ
# @6uAGyHMZ9ifr9Qp 本当の転職理由は会社に残らない良い例…
# 付いたり消えたりするので気にしないことにします…良い記念になりました
# first_flg: False
# RT @glucosamineZ: ちらっと見ましたが、
#
# ・会話形式
# ・しかも美少女キャラ多数
# ・見出しのパロディ感が楽しい
#
# という感じでとっつきやすそう。
#
# Excel関数の擬人化キャラクターが楽しく解説！『関数ちゃんと学ぶエクセル仕事術』の発売を記念して、まえがき～第1…
# @glucosamineZ 編集さんがその本めちゃくちゃ意識してました笑
# @hy_11 ヤススさん、ありがとうございます！
# アイコン使い続けていただいて、嬉しいです！！
# RT @hy_11: 自分のアイコンを描いて下さった
# @Tsutsui0524 さん！
# とうとう書籍の出版まで🐼‼️
# RT @ss60kb: 無味乾燥な関数を擬人化して覚えやすくするのは素晴らしいアイデア
# 脳科学的にも正しいと脳科学者がいいそうですｗ
#
# おまけに全員カワイイから覚えやすい😄
# RT @PRTIMES_ETM: Excel関数の擬人化キャラクターが楽しく解説！ 『関数ちゃんと学ぶエクセル仕事術』の発売を記念して、まえがき～... https://t.co/t8DFuslmux https://t.co/pjgWqXKkW6
# @audiobookrunner ちゃんと動線が確保できているか…大事ですね
#
# 難しい構図をさらりと描かれていてびっくりします笑
# @my_kirakira 言わんこっちゃない笑
# @perfMai017 太字と黄色は目立ちますよね！
# @1RRhcSB6HSUu9hF @mine__0 Excelとおにぎり好物なので笑
# first_flg: False
# @keito_oz 諦めるに一瞬見えてしまいました笑
# @mine__0 色々渡り歩いて、困ってたら助けて、おにぎり貰いたいです
# @MasazaneKunohe 営業力ッッ！
# @tkgsn146 @covcovcover 法に反するコストは高いですね確かに…
# @VBA07529852 投げ銭しなくては！！
# RT @VBA07529852: 来週はこれ！
# 和風スパゲティの配列入門！
# Array &amp; Collection &amp; Dictionary
# 3月18日 20時～
#
# 参加したいひとは、はい れつに並んでねぇ（ズコっ
# @wafu_spaghetti
# #VBAの悩みはVBAerに聞…
# @matudakta あがれそうにない…笑
# @moripro3 もりさん、ありがとうございます！！
# 楽しんでもらえたら、嬉しいですね！
# RT @moripro3: Excelに苦手意識があっても、かわいいキャラと一緒なら楽しく学べそう！
# @derAnfang2021 レイさん、ありがとうございます！
# どうなることやらです！
# first_flg: False
# @okinawa__noodle @marumin21 セルフツッコミ笑
# @mechkawa 営業力に驚いています…！
# @pegat26 あかーん！！
# @RelaxTools RelaxToolsちゃん招き猫説、絶対ありますよコレ
# ありがとうございます！
# @tokagedinosaur ごめんなさい、真剣な質問でしたのに…！
#
# こうして意見が聞けるのはありがたいですよね
# リアルではなかなか関心持たれないですし
# @tokagedinosaur 遠足のおやつ的に聞こえてきました…笑
# @ss60kb ありがとうございます！
# 文字の羅列が、顔の見える相手になると親しみやすさも違ってくるかなと思いました！
# @wachi_dayan 覚えなくて良いです笑
# @RelaxTools Relaxtoolsたんに続いて2度目のピックアップでした
# 感謝です！
# Excelの必須ハンドサイン https://t.co/TkpZWV7hn9
# first_flg: False
# @MasazaneKunohe ブラッディマンディのファルコン感ありますね！！
# かっこいい！！
# @excelspeedup 想像したくないですね…
# RT @matudakta: ヤフーニュースにも出てる！
#
# Excel関数が美少女キャラに!? 初心者にも親しみやすいエクセル解説書の第1章が限定無料公開(Impress Watch)
# #Yahooニュース
# https://t.co/b4aCjYDGXD
# @matudakta @MasazaneKunohe インプレスさんがプレスリリース出してくれた効果ですかね！？
# どうなることやら！ありがとうございます！
# #関数ちゃん の本にベストセラーのリボン（？）が付きました！
# ありがとうございます！ https://t.co/cq8p5en6Ok https://t.co/nzcPpmU4we
# Yahoo!ニュース！！
# 教えてくださってありがとうございます！ https://t.co/zJtfCAGZOc
# 行と列の方向の覚え方をADDRESSちゃんに聞いてみた
#
# #関数ちゃん
# #漫画が読めるハッシュタグ https://t.co/oI1w9QpioS
# RT @RelaxTools: Excel関数が美少女キャラに!? 初心者にも親しみやすいエクセル解説書の第1章が限定無料公開 - Book Watch/ニュース - 窓の杜Group 3Group 3Group 3Group 3 https://t.co/iDyD9DTriw
# @kinsura_hagure 超高速で試行錯誤できる感じですよね
# @pinyiah そうですね
# AIの登場で数式入れるようになったら、儲けものくらいの感覚かもしれないですね
# first_flg: False
# RT @Tsutsui0524: AIがExcelの数式を書いてくれることで、今までExcelに数式を入れたことがない人が数式を入れたり、使ったこと無い関数を使ったりするのは、とても良いことだと思う
# RT @Tsutsui0524: 去年は確定申告の締め切り前日の3月14日にe-Taxが落ちてましたね
# 今年はどうでしょうね https://t.co/EVpxf3xS9x
# @shamo_ken みたら死ぬ
# @ocinfo11 新しい何かを見つけそうな気もしますけど、どうなんでしょうね
# 勉強も労働も不要な世界も見てみたいです
# @StudykExcel これ需要ありますよね〜
# @Excel_design_Dr Excel医先生、ありがとうございます！
# そうなんですよ、かなりネタ多めです！笑
# 関数ちゃん本の試し読みキャンペーンを、窓の杜様が記事にして下さいました！
# 3月17日までです！ https://t.co/8Pgpc8fKP8
# RT @Excel_design_Dr: 目次の見出しが楽しすぎてやばい！
#
# 「IF, IF, IF, IF・・・」
# 「まるでIFのバーゲンセールだな」
#
# とか最高すぎる🤣センスの塊👍
# RT @madonomori: Excel関数が美少女キャラに!? 初心者にも親しみやすいエクセル解説書の第1章が限定無料公開／『関数ちゃんと学ぶエクセル仕事術 実務で役立つExcel関数を擬人化したら？』【Bo… https://t.co/Ckp5uWerQR https:/…
# @johnchung1975 ありがとうございます
# 昨日が搬入日というやつで、早ければ週末に書店に並ぶこともあり得るようです！
# first_flg: False
# RT @Tsutsui0524: #関数ちゃん
# 期間限定で関数ちゃん本の試し読みができます！
# 冒頭〜44ページとなります！
# RT @PRTIMES_NEWS: Excel関数の擬人化キャラクターが楽しく解説！ 『関数ちゃんと学ぶエクセル仕事術』の発売を記念して、まえがき～... https://t.co/cogazlEdlO https://t.co/LwnlfEzuuF
# AIがExcelの数式を書いてくれることで、今までExcelに数式を入れたことがない人が数式を入れたり、使ったこと無い関数を使ったりするのは、とても良いことだと思う
# @N_noir_7 ありがとうございます！
# いつも拡散頂いて、嬉しく思っております！
# @mikimomo_as ありがとうございます！
#
# 恐らく試し読み用のデータに変換するときに色がおかしくなったようで、手元の紙の本ではきちんと印刷されていました
# （これ以外で一箇所やらかしてますが…）
#
# 半角へのこだわり読み取って頂き、ありがとうございます！ https://t.co/w0elilwOz1
# @N_noir_7 なんかめちゃくちゃ面白かったのでリプしてしまいました笑
# @Yu_Ri_SYS ぶきっちょは、今ついてる5本を上手に使えないということではないのです…！？
# @N_noir_7 なんですかこの態度は笑
# @sotto122018952 私は先輩という言葉には特に偉いみたいな意味はなくて、ただ先に入社した人ってことだと思うので、そのままでも良い気がします
# シートの移動方法
# 『F6』キーでシートタブにフォーカスを移動して、方向キー(←→)で移動、Enterでシートをアクティブにする。
#
# シートの中が見れないですが、イベントマクロが動かないので重宝することがあります。 https://t.co/lqqMQQdjiw
# first_flg: False
# @keiriman210529 @glucosamineZ なんでこんな引き出しあるんですか！？笑
# @sangyo_haikibu2 職場の名刺の話ですが、筒井.xlsの名刺が必要なくらい忙しくなると良いですね～！
# さんぱいさん、本の予約ありがとうございます
# 楽しんでもらえると良いのですが…！！
# @matudakta 松田軽太さん、ありがとうございます
# 全体ページに対して結構なページ数読めるんですよね、びっくりしました笑
# @astrophys_tan ええーっ！！！
# @Yu_Ri_SYS 大量にシュレッダーにかけるのも、なかなか辛いですよ…笑
# @johnchung1975 John Chungさん、ありがとうございます！！
# 感無量です…！！
# さすがのForguncyさん…！！ https://t.co/G7SHaAEAOn
# RT @shota_Excellent: Excel関数の擬人化キャラクターが楽しく解説！『関数ちゃんと学ぶエクセル仕事術』の発売を記念して、まえがき～第1章を先行無料公開 #SmartNews  https://t.co/UGiha7jk5K
# @StudykExcel やさしい言葉で分かりやすい記事でした！
# サンプルも珍しい形で、工夫されているように思いました
#
# 最後まとめのところが「数字を入力すというよりも…」となっていましたよ～
# @Yu_Ri_SYS なんだか安心しました笑
# 私も年数枚くらいのペースです…
# first_flg: False
# 「売上高のセルを選択して下さい」
# 「取引先コードのセルを選択して下さい」
#
# 処理するフォームがバラバラ過ぎて一部対話っぽい作りにしてるVBAが、社内ではAIってことになってて笑う
# 恐ろしく名刺が減らない
# @TweetingKacy いるって言われたらどうするつもりなんでしょう笑
# @kinuasa バズるを勘違いしていそうですね…
# RT @matudakta: 関数ちゃん本、お試しでけっこうなページ数が読めるよーーー！！
# @ezokanzo 詞乃先生ありがとうございます！
# とにかく1冊読み切るハードルは低いのではないかと…！
# RT @johnchung1975: 私が尊敬する画伯の本がいよいよ数日後に発売されます♪
# 「Excel？なにそれ？画質？」
# 「エクセル？仮面ライダー？」
# などExcelになじみのない方は社会に出てスキルの有無で差がつけられますので、気軽に読める入門の入門として是非一家に一冊♪…
# @RJc8odOULWBPoq4 @KotorinChunChun なるほど、失神…
# RT @Tsutsui0524: セル範囲同士が一致しているかどうかを判定する数式
# AND関数の使い方が渋い！
#
# &lt;例で使用している数式&gt;
# （配列数式です。スピル非対応バージョンでは Ctrl + Shift + Enterで数式を確定して下さい）
#
# =IF(AND(B3:D5…
# #関数ちゃん
# 期間限定で関数ちゃん本の試し読みができます！
# 冒頭〜44ページとなります！ https://t.co/C5bC5FThUV
# first_flg: False
# RT @dekirunet: Excel関数の擬人化キャラクターが楽しく解説！『関数ちゃんと学ぶエクセル仕事術』の発売を記念して、まえがき～第1章を先行無料公開 https://t.co/K0dkKTv9QY https://t.co/8oHp0OLeDi
# RT @impress_corp: ／
# 3/14（火）発売『関数ちゃんと学ぶエクセル仕事術』
# まえがき～第1章 無料公開キャンペーン
# ＼
#
# 発売前に書籍の一部が読めちゃう！ 擬人化されたExcel関数たちと一緒に楽しく使い方を学びましょう！ 17日までの公開です。
#
# #無料公開…
# @KotorinChunChun 譲る気ないんですね…
#
# こういうツイートするということは、Microsoftは困っている人がいることはよく知っていて、その上で我々が決めた正しい改行の操作を行えよっていうスタンスなんだなと笑
# 寄り添うように見せかけてそうでないっていう…
# @RJc8odOULWBPoq4 @KotorinChunChun 会社で寝るというのは基本なんですね…
# @mechkawa この絵とても好きです
# 良い成分が含まれています
# RT @Tsutsui0524: （いや、まずEnter単体で送信をやめる選択肢…） https://t.co/uIPnLsUjg0
# @KotorinChunChun ちゅんさんの徹底調査本当凄いですよね！
# 今やったら違っていたりするんでしょうか…
# @KotorinChunChun いや、普通に椅子で寝た経験の話されるの怖いんですが…！？
# RT @ShiodaKayak: 実は…、信じてもらえるかわからないんだけど、改行以外の目的でEnter押さなきゃいけない人たちが世の中にはいるんだよ…
# @OElwLDyW1tHGhvq ぬこ.shさんありがとうございます…！！
# 使えそうな場面があれば是非！使ってみてください！
# first_flg: False
# 予約しました！
#
# 著者プロフィール『30代内科医。Excel大好きVBAer。職場のあだ名は「Excelの神」。』
# タイトルはここから…？？
# やっぱり神様だったんですね笑 https://t.co/7wjH2AZzJQ https://t.co/8MEEZk87gD
# @Variable_Wand なめっちさん、ありがとうございます！！
# @Sagittarius8083 調べてきました
# 兄者と弟者のやつですね！笑
# 確かに似てますね…！！
# RT @Tsutsui0524: 『F2キー』
# セルを編集する
#
# シンプルですが、かなり快適になります
# セルのダブルクリックには、遥か彼方へ吹っ飛ばされる問題が…
# #Excel https://t.co/x3Ken877nC
# @RigelWired 硬くする方向より柔らかくする方向の方が簡単そうなのは、壁にぶつかった側の音が大きいからなんですかね〜
# @shimochan_dayo 見逃すところでした！
# ありがとうございます！
# RT @shimochan_dayo: ふふふ🤭 https://t.co/SUIslNJRBq
# @ShinkumiNoHito @mikimomo_as 頭いいですね…！！
# 10日！
# おはようございます
#
# =NOW()
#
# Excel関数 NOW関数が
# 2023/03/10 4:13 をお知らせします https://t.co/4imgkZ8dNV
# RT @ticktackworker: 自分より上手い人にこんなこと言うのもなんですが‥
# 最近、筒井さんの画力がどんどん向上してると感じる。
#
# まだ成長するのね✨さすが😆
# first_flg: False
# RT @ticktackworker: たびたび申し訳ございません💦
# アンデッドに続き、フクロウが脱走し‥て‥ません！！😫
#
# ずーーーっと同じところで止まってます😭
#
# フクロウだから昼間は動かず、フクロウなのに首が回らないという不器用な二面性を持っているようです✨
#
# #IT珍獣…
# @ticktackworker 可愛いコレ・・・！！
# あいづちはするの良いですね笑
# RT @KotorinChunChun: ほんとほんとｗ
# もはやTeamsさんとは分かれられない運命にあるので、どうか仕様変更（オプションの追加）をお願いしたい。
# RT @AkiraYukizaki: 文字列にしないと…！
# 利するとディスるって音が似てるし、
# 誰かをディスることが、かえってその誰かを利することも多い
# RT @kikikillinge: これ分かるわぁ〜。
# 前の会社に「気づいたことどんどん言って！的外れでも構わないから！(ただし機嫌が悪くならないとは言ってない」の人いた。
# @TakahiroMaeda3 exeにすればPython入ってなくても動きますもんね
# 関数ちゃんのLINEスタンプ作りました！
# 16個セットで120円です
#
# 今度はExcel関数擬人化ではなく、関数ちゃんです…！！
#
# #関数ちゃん #広告
# LINEスタンプ購入ページ
# https://t.co/RheZOIVPd6 https://t.co/pGODPQllDy
# RT @Tsutsui0524: 上司「よう、頼んだマクロは作ってくれたか？」
#
# 事務員「私はもうマクロは作りません」
#
# ...
#
# そうきたか…と😭
# @osatoexcel おささんのこれからの活動が楽しみです！
# 役員PCのログインパスワード変更（2つを交互に使用）ヨシ！！
# @MasazaneKunohe 笑えるようなこと、起きますからね https://t.co/jhL2X9AXtc
# @ankoromochi7793 じゃあ障害物水泳がないと不公平ですね！
# さむいふ関数ちゃん
# #関数ちゃん
#
# SUMIFちゃん解説ブログ記事
# https://t.co/whk1cuCLMJ https://t.co/30ORVXgJjy
# 『 Shift + F9 』
# アクティブなシートだけを再計算
#
# 他シートに重たい数式が入っている場合は、再計算をアクティブシートに絞ったほうが早いです。
#
# ただし、再計算されない他シートをアクティブシートから参照している場合、更新されないので『F9』ですべてのシートを再計算しましょう https://t.co/u1R0BNHfal
# first_flg: False
# RT @lw0j_chirarin: 置換！あーっ！！！
# @matudakta 私はSUMIF関数のヘルプデスクか？って思うことありましたね笑
# 大事な格言なのでリツイートします https://t.co/kyS4QXkmY2
# @hoehoe1234 @yamato_1413 その筋力がいつか…！！
# @wafu_spaghetti 普通にレシピが引っかかりそうですね笑
# @mine__0 ボイスチェンジャーで対抗だっ
# 水泳競技は泳法が分かれていて、最速ではない泳法が消えないの何故なんでしょう
#
# 男子100メートルNARUTO走り決勝とか見てみたいのに
# @consultnt_a 男性は生涯子供ということで
# @ivuki_works このイラスト可愛いです！
# 目力ですかね、引き込まれます
# @kadukijob アフィリエイト貼るとそれなりに儲かることがあるので、売れなさそうなもの、福祉的なもののアフィリエイトが良いのでしょうね
# first_flg: False
# @mikimomo_as @fe_excel ※以下を書かなくて済む世の中になってほしいものです
# 楽しませていただきました！
# @marumin21 つい、うっかり！笑
# @yukiyama2003 @soluey3 Adobe Acrobat Readerに決まってます
# @grinch_ip おお、まさにそんな感じで見失う前を残して欲しいのですよね
# 参照を返す関数がエラー出す時は今のままで良いので、手がかりを残して欲しいです笑
# RT @sakatomiku: Excelで数字の表し方を変更するショートカットを
# 筒井.xlsさん（@Tsutsui0524）が紹介しています⬇
#
# あんまり数字は扱わない...という人も
# Ctrl + Shift + 6は覚えとくと便利✨
# サクッと外枠書きたいときに！
#
# 反対…
# RT @kazu_cx: 非表示の列やら行やらあってですね、、
# そこに地雷があったりしてねぇ
# 社員「この機械を入れれば省人化で人件費削減になります！」
#
# 役員「そうか…今まで機械ができる仕事にこんなに給料を…」
#
# 社員「な～んか上手く伝わっとらんね」
# Excel「#REF! 参照セルを見失いました」
#
# 私「最後にどこで見たか分かる？」
#
# Excel「#REF!」
#
# 私「えっと…最後にどこで」
#
# Excel「#REF!」
# 上司「話す時は数字で話せ」
#
# 部下「はい」
#
# 上司「資料、なるべく早くたのむ」
#
# 部下「これはええんか？（はい）」
# @Betelgeuse0001 =DAY(DATE(A1,2,29))&gt;1
#
# これで1字減らせるらしいですよ
# first_flg: False
# くっそ～
# 分かってても2023年12月の日付を入力してしまう…！！ https://t.co/bpokWrwmNs
# @tako_and_kitune ううっ…
# @marumin21 メールが届かない仕組みにしなくては
#
# https://t.co/3Mjt5fjc23
# @soluey3 @yukiyama2003 なんか認証くぐり抜けたら向こう側に行けそうな予感！！
# @yukiyama2003 ワシの認証は108段階まであるぞ
# お腹がすいたので表示形式の「#,##0」がベルギーワッフルとドーナツに見えてきました
# RT @EdTinker7: 交通費精算のシートに往復の金額入れて渡したら、「そのセルは数式が入ってるんです！往復の場合はこの欄に２！この欄に片道金額！を入れて下さい！勝手に数式変えないでください！💢」ってめっちゃ叱られて、『知るかよ～～！💢💢』って心で叫びながら「あ～ゴメンゴ…
# @mikimomo_as =TYPE(("29Feb"&amp;A1)*1)=1
#
# 戯れてみましたが短くはならず…
# こういうの考えてると、専用関数が無くて良かったと思います（？）
# 年末に伝えた、聞いていないの言い争いはやめろ～～
# =TYPE((A2&amp;"-2-29")*1)=1
#
# ここまでか～ https://t.co/wSByCXVZ9R
# first_flg: False
# RT @Tsutsui0524: 私「12/28って入力したら、ふつう去年のことだと思わない！？」
#
# Excel「いや、ずいぶん気の早い話をするんだなぁと…」
# @mikimomo_as ありがとうございます
#
# 質問しておきながら良い数式が出ずでした…
# 他の人の回答見て「2000-3」が2000年3月1日のシリアル値返すんだと勉強になりました
# RT @Tsutsui0524: 本当の退職理由は企業の人事ではなく、Twitterに集積されている
# RT @kimura_haduki: 人による作業があるから人によるチェックが必要になる流れ。
# これにExcelが出力したから問題ないという人は経理として書類チェックすれば意味がわかる。
# RT @Excel_design_Dr: マジでF2, F4, F12だけ覚えて！
#
# Excelファンクションキーこれだけ覚えて！F2 F4 F12　https://t.co/kkWeol8V6P https://t.co/J88kmAZRcd
# @kyuratan 永続版でOneDrive接続って便利なんですか？
# @toshi81350036 うちの場合ですが、配られた資料を見た人が確認できる範囲での検算はしておく感じですかね
# 元のExcelがあればExcelで検算すれば良いですが、やはり不安は拭えません
# 役員PC旧パス「もしかして…私たち」
# 役員PC新パス「もしかして…私たち」
#
# 旧&amp;新パス「入れ替わってる～！？」
# Excelは見た目が9割！？
#
# 見た目を整えるショートカットキーをまとめました！ https://t.co/zsEAKr6uwY
# first_flg: False
# @aero_iki いきさんが作る模様、色彩と相性良い感じですかね？
# 最早何が出てきてもおかしくないですね笑
# @aero_iki これ以上手に入れてはいけない…
# RT @keito_oz: リンゴ1個とミカン1個は「足せない」んだけど、リンゴとミカンをいずれも果物の仲間として抽象化すると、リンゴ1個とミカン1個は果物2個と数えられる、つまり「足せる」。
#
# 複式簿記でも似たようなことをやっていて、現金100円と売掛金100円は足せないが、…
# @mechkawa 私もTOM先生のイラスト魅力的だと思います！
# コンポート美味しいですよね、次の誰かの誕生日が楽しみです！
# 本当の退職理由は企業の人事ではなく、Twitterに集積されている
# @akizyu1 普通は分かりますし、検算の結果正しいことが多いですよ
# RT @sachiee: 今、まさにその状況😭
# 日付でソートしたら、入力した行が消えた！？
# あれぇ？と思ったら一番下にあった。表示形式がmm/ddになっていたので、うっかりしてました。
# 「Excelを電卓で検算する」という行為、ネタにされますけど経理では結構やります
# 人が作ったExcelには不安が残りますからね
# RT @rifusama: この季節は手動で年を入力する季節だと思って割り切ってる
#
# そんな社会人20年目
# RT @t_yoshi_tomi: 「入力したデータが消えた！」って焦ったら、今年の12月のところにいたっていうことが毎年１月２月３月によくある
# first_flg: False
# RT @Tsutsui0524: ネ申Excel https://t.co/cQHpTiwIVl
# これやったら上司に即戻せと指示された思い出が…
# 重なりに強くて良い感じだったのに https://t.co/t6XAPACCTf
# RT @careerlost: 年明けの仕事あるある。
# @mikimomo_as 1900年を閏年とするのはOKですか？
# RT @fe_excel: =DAY((A1&amp;-3)-1)=29
# 17文字以下は思いつかず。
# @VBA07529852 さすがの仕事ぶりでございます
# @KotorinChunChun Ctrl + Enterって、そういう時は意外に出ませんよね（そこ！？）
# @yh_excelmuzui これこれ、こういうのが好きです！
# 私「12/28って入力したら、ふつう去年のことだと思わない！？」
#
# Excel「いや、ずいぶん気の早い話をするんだなぁと…」
# first_flg: False
# RT @VBA07529852: 売上管理Excelが動かないと急遽のご依頼。PC変更・DropBox設定変化等によりWeb版Excel起動だったり読み取り専用だったりな原因。
# 調査、対処、原因解説、OneDrive設定等して利便性・安全性向上までで約1時間。
# うふふ今日も人の…
# @IT_craftmanship 鯛はここまで進化しているんです？？
# 「倉庫にゴミを放置するな」と掲示しても、倉庫をゴミ置き場だと思っている人は自分のことだと思わないので行動を改めることはない
# @aero_iki いやいやいや
# 偶然できたとかじゃなくて、見た柄模倣できるんですか？
# 目に入るもの全部数式で見えているとかなんです？？
# びっくりし過ぎて怖いくらいです笑
# @hi_fumiyo 今回も可愛い車擬人化ちゃんですね
# 柔らかい感じ！素敵です！
# RT @hi_fumiyo: ND型ロードスターと擬人化、描かせていただきました。ご依頼ありがとうございました！ #車擬人 https://t.co/4x490luQdx
# @mahusukaya そこまで妄想が膨らむとは…
# @my_kirakira 作りれますよね！
# やっぱりCONCATちゃんはものが違う！
#
# #関数ちゃん
# CONCAT関数 擬人化キャラクター解説！エクセル関数の機能や使い方を図やイラストでかんたんに説明します！ https://t.co/XHDi93DwPv
# @my_kirakira それが関数です笑
# first_flg: False
# ただし戻り値は尻から出る
# @6uAGyHMZ9ifr9Qp 最低限で選定しました！
# @toshi81350036 指摘して教育する義務もないんですけどね
# ただ、文句言う労力で教えてあげられたんじゃないか？と思える長文だったりすると勿体無さを感じます笑
# イラストのトリミング（切り取り）がよく分からない
# 元はこんな感じでした
#
# 構図の勉強する絶対 https://t.co/F39PcWWNgk https://t.co/PnSPL7aiie
# @consultnt_a 他人に行動を起こさせたのだから、大したものですよね
# 私も同じこと考えてました笑
# @matudakta @easy12110 下に猫ちゃん並んでるのもなんかヨシ！
# @rootassist 言われてみればたしかに？？
# 13月も33日も無いという安心感からですかね？笑
# RT @mikimomo_as: ざっくりでよければ
# ・Excelの「並べ替え」を左端の列で行ってある状態
#
# 細かく言えば
# ・検索値と同じデータ型で、左端の列にある値を不等号で比較したとき、より小さいものが上の行にある“昇順”で並んでいる状態
#
# 検索するのは検索範囲の真ん中から…
# @RelaxTools Relaxtoolsちゃんが！！
# @toshi81350036 その辺寛容になれない人はいるみたいですね
# 敷居を高くすると廃れてしまうと思うのですけどね
# first_flg: False
# パソコン買ったので届くのが楽しみ
# #VALUE! → オープン価格
# #NAME? → 舐めてる？
# #NULL! → セルがヌルヌルだ
# #NUM! → 南無!どうにでもなれ！
# #CALC! → カルシウム不足
# #N/A → んなぁ～
# 『1,000円』は文字列になるからダメで、『¥1000』は数値になるからOKって説明するの難しい https://t.co/9gWG0tzl7f
# RT @Tsutsui0524: 500キロカロリー…
#
# デリシャスパーティプリキュア、来年はおかわり！にならないかな〜と期待してました
#
# #プリキュア
# #precure https://t.co/r6czUkuXCx
# RT @TamaMaruyama: Excelで複数ブックで作業している時に、Ctrl➕Zで、戻って欲しくない方の、ブックに影響あるの、私だけかなぁ？設定で変えられるのかな？何とかしてクレメンス。
# RT @tkgsn146: ≪ITAINO444, OSAKA TOWER. UNABLE TO ISSUE LANDING CLEARANCE, FIELD IMC, CEILING  60 FEET, VISIBILITY 500 METERS.≫
#
# ＿人人人人人人人人人人…
# Ctrlキー
# 単体で押した段階では何も起きないので、安心して押してくださいと伝えています！
#
# ショートカットの第一歩です https://t.co/3M0QAeWPmB
# RT @nal_dal_dere: セルの中にIFのネストすると読みにくくなるから、出来るだけVBAの方に書きたいのだけど。
# さっき頼まれたのに納期が今日の17時みたいな場合は、もうIFのネストで無理矢理やったるぜって気になる。
# 母「いたいのいたいの、とんでいけ～」
#
# 子「どこにとんでいくの？」
#
# 母「伊丹空港よ」
# 変数i「やべ…降りる値寝過ごした」
# first_flg: False
# @furyutei そう言っていたのかも…
# @ankoromochi7793 他方位に失礼すぎる笑
# 子供「お友達のお父さんはDIOが上手なんだよ」
#
# 私「本当にDIOって言ってた？」
# @naruse045 頼りになりますよね！
# IF関数をネストすれば何だってできる
# あの頃の私たちは、それがExcelの真実だと、そう信じていたー
#
# #関数ちゃん
# エクセル関数IF関数擬人化キャラクターで初心者向け解説 機能や使い方を簡単に説明します https://t.co/g5k68aaImq
# RT @Tsutsui0524: INDEX MATCHは尊い
# INDEXちゃんが輝いて見える…！
#
# MATCH関数とINDEX関数のネストで表から検索値の左側の値を取得 数式を擬人化キャラで解説します https://t.co/JgYX5JAW6e
# @actiolic めちゃくちゃ楽しそうです！
# 今年の目標が達成するための準備を去年終わらせたので、今年の目標は来年の目標を達成するための準備を終えることです
# ネ申Excel https://t.co/cQHpTiwIVl
# 今年の十二支
#
# =MID("子丑寅卯辰巳午未申酉戌亥",MOD(YEAR(TODAY())+8,12)+1,1)
#
# あけましておめでとうございます！
# 今年もよろしくお願いします！
# first_flg: False
# @mentarugarasu0 あけましておめでとうございます！
# ありがとうございます！
# 今年も大変お世話になりました
# ありがとうございました
#
# =NOW()
#
# Excel関数 NOW関数が
# 2022/12/31 23:55 をお知らせします https://t.co/8E8bQE6V5f
# @KotorinChunChun 書式設定…
# それはそれで書式によって引数変わったり変わらなかったりでややこしいですね
# RT @KotorinChunChun: これって書式設定が関係してたような気が……
# RT @6uAGyHMZ9ifr9Qp: 前職までいた開発職では、
# 本読め、論文読め、24時間考えろって
# トンガリを育てる方針で、それはそれで辛かったけど
# 育つ見込みのない輩を何とかしろというムチャ振りはなかった。
#
# その会社当時メチャクチャ儲かってたな。 https://t.…
# @ma_anago 分かりやすすぎる例えですね笑
# 私「今年も一緒に色々作ったね～」
# Excel「来年も宜しくおねがいします」
#
# 私「ところで1/6は…」
# Excel「2022/1/6ですね。歴然に。一片の淀み無く。」
# 年始に親戚の子供と遊ぶこともあると思いますが、年月が経つと「子供と遊んであげる」じゃなくて「子供が遊んでくれる」だったということに気付きます
# 2022年振り返り
#
# [6月]
# Excel ファイルの計算式ミスで補助金過大支給、数億円規模か
#
# [10月]
# 「エクセル任せで点検不十分」　マイナス収支で「△三角」と誤入力
#
# [10月]
# コロナ個人情報のメール、111人に誤送信　エクセルの操作ミス原因
# @TetsuyaUshio @grinch_ip OFFSET関数の便利な使い方！
# 例えばこんなことありますよね？
# あれ？参照伸びてますね？
#
# ってなるんです…
# first_flg: False
# @marumin21 カニカニランチ笑
# 口に出したいワード！！
# RT @Tsutsui0524: 出勤最終日のプレス加工名人に言われた
# 「気をつけなあ、会社が採用のとき俺に求めた突出した技能は風向きによっちゃ属人化と言われて叩かれ、会社で過ごす時間の多くは自身の研鑽の為ではなくヤル気のない奴らを普通に働けるレベルまで育てることに費やされるこ…
# いそがしくてイラストの依頼とか断りまくっててすいません
#
# かと言って、プロフ欄に現在依頼は受けられませんと書くほどの絵師ではないっていう…
# @nitoukinnosuke それは大変ですね
# 一刻も早く良くなることを願っております！
# RT @grinch_ip: マジで?!いつから?!
#
# 行挿入時に参照を追従させるために、わざわざOFFSET関数で「自セルの1つ上」を参照させる様にしてたと言うのに。
# でもこの挙動もどこまで信頼していいのか、いつまで続くのか分からないから結局OFFSET参照させるしかないんだ…
# RT @kenken_patent: チェックシートやExcelを使えば誰でもすぐに出来るような業務を、そういう工夫を拒否して個人に｢属人化｣してるケースもあってだな…😔
# RT @nekokure1984: 正直、Excelやシステムが苦手でも若手ならまだいい。教えればいくらでも伸び代はあるから。
#
# 年配のやる気のない社員に教える時ほど大変なことはない。
#
# 教えてもなかなか覚えてくれないし、酷い時には、今までのやり方に固執して逆に説教してきたりも…
# 「この関数便利そう！試してみよ！」
# っていう時にバージョン足りてない時のもどかしさ…
#
# Excel関数バージョン対応表です https://t.co/FWzrwSdxyv
# @nakayoshix 永遠を誓うカップルのようですね笑
# @keiriman210529 使ってみたら便利すぎて驚いてます
# first_flg: False
# たしかに欲しい… https://t.co/PMFX5iCuma
# @kanrekisugita いつが大事、その通りですね
# 事業の過渡期でフローが固まっていない状態で、当事者がVBAで対応する以上の策があれば良いのですが、それはなかなか無いのではないかと思っています
# #関数ちゃん
#
# 今年は既存のブラッシュアップに費やしたので、
# 来年は新しい子がお目見えできるかと思います
# @matsbox きたきたきたー！！
# RT @matsbox: 12月31日、大晦日（おおみそか）。
# 大祓で穢れを祓い、除夜の鐘で煩悩を除く年越しの日。今年最後の締めくくり！
# #暦日擬人化2022 https://t.co/5ia3yTrEGs
# RT @mikimomo_as: #数式が1文字でも短く出来た人が勝ち選手権
# A1に1900～9998までの4桁の数値を入れました。
# その数値の年号がうるう年ならTRUE、そうでないならFALSE（または0以外の数値(=TRUE)と0(=FALSE)）を出す数式を書いてください…
# RT @matudakta: 「君しかシステムを作れないんじゃ困るんだよ！誰でも出来るように人材育成するもの君の役目なんだぞ！」
#
# って説教垂れるなら育成する人材というヤツを見つけてきてくんかのう？
# 出勤最終日のプレス加工名人に言われた
# 「気をつけなあ、会社が採用のとき俺に求めた突出した技能は風向きによっちゃ属人化と言われて叩かれ、会社で過ごす時間の多くは自身の研鑽の為ではなくヤル気のない奴らを普通に働けるレベルまで育てることに費やされることになるんだあ」
# @trc_games @tsuuhuu フラグです
# first_flg: False
# @toshi81350036 ツイ廃御用達！！
# RT @VBA07529852: 今夜でーす!
# #VBAの悩みはVBAerに聞け
# 「このマクロが間違っているかもしれないのにボタンなんて押せるか！俺は手作業に戻るぞ！」
# iPhoneの文字入力だと、三本指で左にスワイプで戻す、右にスワイプでやり直しなの便利ですね https://t.co/0FU8M6MXv9
# あの〜、納まってませんけど？ https://t.co/V72MhFp6T2
# @trc_games それは初めて効きました
# totalじゃなくて良いんですね！？
# @trc_games なんか定番のミス再現できなくて悔しかったです
# 真下ではないケースでも伸びたりはしませんでした
# 表の一番下にデータ追加したら、SUM関数の参照が足りて無くて数字が間違ってました！
#
# …っていうミスをした記憶があるのに、今試したら追加した分SUM関数の参照も伸びたんですが！？
# あの失敗の記憶は私の経験ではなく、嘘の記憶が植え付けられているということ？？ https://t.co/s8284BmUHv
# @apis_r 仕事の難しいところはそこですよね…
# 逆に自分が喜ぶ、それで良いを容認してくれる仕事なら…
# @my_kirakira 関数擬人化とか、ニッチもいいところ…笑
# first_flg: False
# 響きました https://t.co/vgCcZZcnem
# @apis_r これ！いいですね！！
# ブクマしました
# ニッチ最高…！！
# @HighWiz @sugoi_kaizen 作ったものが社内展開されるだけで使用料取れないとか、そういうことでしょうか
# @nikuq_hirosawa ありがとうございます笑
# @HighWiz @sugoi_kaizen レバレッジが効きやすいのがプログラミングの強みということでしょうか
# 興味深いです
# RT @Tsutsui0524: 自転車を勝手に持ち出された挙げ句「運転していたらケガをした」「なぜ鍵をかけていなかった」と怒られるのと同等の理不尽を自作マクロで味わう
# #2022年自分が選ぶ今年の4枚 https://t.co/ud2CRnAfXV
# @tkgsn146 書体がゴージャスですね笑
# 最前面に表示されることなく、タスクバーの右端に現れてOKボタン押さないと進めないウインドウなんなの？
# RT @YainuHonda: ドラマリスト作ってる時の私じゃないか
# first_flg: False
# @wafu_spaghetti @blacklist_ryu 偉業です！
# @ExcelQBag どんな鉄壁ですか！？
# 全部身の回りのことをご自身で！？
# おつかれさまでした！
# @shino65536 使ったことないですけど、便利なんですかね
# 色々ツッコミ入れるのでしょうけど
# @PowerpointF 影がいい感じに切り絵感出てますね、
# Excelだと思いませんでした
# RT @TapiTapiPudding: 多分12月は2022を2023に直す作業だけでトータル1時間くらいやってる
# 365のExcelでは一枚目がコメント、二枚目がメモといいます
# メモは従来のコメントのことです
#
# ややこし！！ https://t.co/Y5f5DOCdsW
# RT @CyberKennel_jp: 1つずつコピペの部下職員に、VLOOKUPで並べ替えして貼り付け先と同じ体裁で整えてからコピペすれば楽で速いと教えたら、目をぱちくり
#
# VLOOKUP知らないのもあれだけど、「前任者の手法で自分もやるするしかない」という思い込みが業務の省…
# @matudakta 面倒にはミスもつきものですからね！
# 今年の未送信ツイートは今年の内に処分しましょう
# @nixuko くやしくなんか…
# first_flg: False
# @kymmt867 まぁ、こういうので改善したと騒いでる人見つけたら、すごいねって言ってあげてください
# @rider_chari 今はSORT関数がいい感じにしてくれるんでしょうかね
# @pippi_vba 悔しくなんか… https://t.co/Lk0NJQwXv7
# @pchidemaru 小さいかもしれないですけど、面倒だと感じる作業を無くせるのは大きいですよね！
# RT @yoti4423yoti: 逆に1月になって、去年の12月の日付を入れたら今年の12月だと判断する。
# そこら辺は人間が判断して西暦から入れにはならないってのは分かるんだけどめんどくさいのはめんどくさい。
# 初めてVLOOKUP関数を自分で使ったのは、貼付け作業に嫌気がさした時でした。
# データを貼付け先と同じ順番に並び替えるために使いました。
#
# これも小さいですけど効率化ですよね！
#
# #Excel https://t.co/SNt77vLrNn
# RT @T_SaX_From_Tp: 私もこれから始めてみます。
# @excel_niisan ポケモンはそのカテゴリ合ってるんですかね？笑
# やっぱり国民的ゲームを圧倒するのは世界を牛耳るゲームですね！
# RT @Honey910Y: うちのExcelくんもこれで、仕事納めなのにデータが取り込めず難儀しました。
#
# 年末年始はExcelくんと必ずひと悶着ありますね。
# RT @Tsutsui0524: VLOOKUP https://t.co/L3N5VCP1c8
# first_flg: False
# RT @koroo012: 仕事でタイムリーに使えるので今後使います！
# @RFStroheim 先頭の20は省けますけどダメですかね
# RT @Tsutsui0524: Excelのロゴ、初期からXLがモチーフで2013でXだけになったと思いきや、最新版にはうっすらとL…？？ https://t.co/fK0LkWBqHT
# RT @Tsutsui0524: 202ʒ年1月1日
#
# 手書きの日付、しばらくこんな感じの修正されますよね
# RT @Tsutsui0524: 私「今日1/6って入れたら2023年のことだと思わない！？」
#
# Excel「微塵も思いませんな」
# @EXCEL_SPILLER アイコンから伝わってきます笑
# RT @guwappa1: 「Excelには日付は西暦から入力する」と義務教育で教えた方がいいね
# RT @rolly_jp: 確定申告とかだと年明けてから昨年分を処理するからねえ…
# 入力しているデータのカテゴリを把握して何年かを判断できるAIが導入されたらいけるかもだけど中途半端な判定処理は更なるムキィーを招くだけ
# @_reime 仕事も自動化しましょう！
# RT @Excel_design_Dr: 最低限これだけは覚えとけ！っていうショートカット10個ずつ選んどいた👇 https://t.co/cCHhsIF89s
# first_flg: False
# RT @sakatomiku: Excelで間違いやすい年末年始の日付入力
#
# ミスを防ぐ方法を筒井.xlsさん（@Tsutsui0524）が
# 解説しています↓
#
# 入力する内容を制限する「データの入力規則」
# ＆
# 日付の範囲を「ENONTH関数」で条件指定
#
# という内容は難しいよう…
# RT @_reime: = DATEDIFF (←なぜか計算できない)
# RT @Tsutsui0524: MATCHちゃんはVBAでもお世話になるし、偉い関数！
# #関数ちゃん
#
# エクセル関数 MATCH関数の使い方を擬人化キャラクターで解説 使い方や機能についてかんたんに解説します https://t.co/iMlLJFCsvc
# @KotorinChunChun 3ミリ隙間があれば侵入します
# 物にぶつかるとしがみつくので、干している服や外出中着ている服にくっついて侵入してきます
# RT @angela_wizard: これおぶこれ(_・ω・)_ﾊﾞｧﾝ
#
# 毎年ね…11月くらいから注意喚起するんだけど毎年新人ちゃんがやらかすんだなァ
# 202ʒ年1月1日
#
# 手書きの日付、しばらくこんな感じの修正されますよね
# パワークエリ勉強するのに最初に読みました
# この一冊でPDFの請求書を整形してデータ化、
# 為替レートをサイトから取得してリスト化できるようになりました
#
# Excel2016だと画面表示がところどころ違っていましたが、読み進めるには問題ありませんでした
#
# https://t.co/m4AuIbLeCo
# RT @gotasora: まさに昨日と今日、複数のスケジュール管理担当が、これExcelさんにやられてエラー出まくりで憤死しそうになってたわ。
# 「一回、年から入れてみ？」って言ったら即解決してた。
# 己を突き通すExcelさん、むしろ眩しい。
# RT @onigiri36721865: 今日ずっとこれ
# @_reime 今年最後の！ありがたや〜！
# おつかれさまでした！
# first_flg: False
# RT @Tsutsui0524: 対応策ですが、セルの入力規則にTODAY関数を利用して「今日より30日前～今日から30日後」の範囲から外れる日付を入力できないように設定できます
#
# ブログで方法を紹介しています
# https://t.co/HffJEb3VwO
# 対応策ですが、セルの入力規則にTODAY関数を利用して「今日より30日前～今日から30日後」の範囲から外れる日付を入力できないように設定できます
#
# ブログで方法を紹介しています
# https://t.co/HffJEb3VwO
# RT @krsnrk61: くっそわかる
# 過去一置換使ってる
# @minami_suiha サムネの右側結構好きなんですけど…笑
# @mine__0 そういうのもあるみたいですけど
# 自分がリツイートしたツイートの表示回数が伸びるのが怖いんですよ
# RT @fW5PCPkl9KoquLV: 普通に4分の1とか4分の2って入れたいのに日付に勝手に変換しちゃうエクセルくん、お節介やめて
# 表示回数が見えるようになって、リツイートがしにくくなったように感じます
# その内慣れるのでしょうけど
# RT @kerlon_fm: Excelがインプットになるプログラムを書いたときに、日付の年数が過去日になっていたら、次の年として変換して取り込むみたいな処理を入れた記憶がｗ
# ショートカットキーの一覧を見ると
# 「こんな機能あったんだ！」とか「あの機能にショートカットキーあったんだ！」といった発見がありますよね
# 以前は目に留まらなかったものが目に留まったり
#
# #Excel https://t.co/F2xGwlKpEs
# @0612Xlookup3 Eの冷遇され具合やばいですよね
# first_flg: False
# @atesan119 それ私も思いました
# L意識してそうですね
# Excelのロゴ、初期からXLがモチーフで2013でXだけになったと思いきや、最新版にはうっすらとL…？？ https://t.co/fK0LkWBqHT
# RT @waenavi_jp: 合同式は高校数学Aで習うらしい。
# できれば中学でやってほしい。
#
# 【Excel・MOD関数】余りの周期性や規則性を利用して、同じ数字の繰り返しを考える
# https://t.co/sjXBS3H1Oy
# RT @teihen_escape: エクセル作業の年末あるあるですね😇
# そして、年が明けてから12月の日付を入力するとその年の12月になっちゃって困る問題も漏れなくセットでついてくる😇
#
# そんな生真面目なエクセルって相棒を、それでも愛せるかどうかだよな、とか仕事納めの日の朝に…
# RT @apis_r: 『コレどうやって運転すんの？走れないんだけど』『ブレーキってどこ？』レベルの文句も出たりする
# RT @nakagawa_cycle: 前後６ヶ月に解釈してほしいと思ってはや30年
# VLOOKUP https://t.co/L3N5VCP1c8
# @tweet_nakasho みんなでタービン回しているところへ行ってテレビ見れば解決
# @Shiromaru_USCPA 日本語読めない人、結構な割合でいると思います
# @GPecaX6y7ApCqbI 色使いが綺麗でかわいいです
# 火の用心でお願いしますね笑
# first_flg: False
# @beConjuror ちゃんと同じ窓なの凄いですね…
# @mikimomo_as @matudakta 光希桃先生の伝説の始まり…
# RT @Bifiniberg: 自作のマクロを勝手に他者の業務フローに組み込まれて、なし崩し的にマクロのメンテだけでなく業務本体でのコミッションも求められるという地獄を味わって以来、「最近はほとんど自分でコーディングしていないので、VBAは何が書いてあるかわかる程度の知識です」…
# @toshi81350036 漫画の同じ技が2度通じないやつみたいですね
# そういうキャラも実は苦労してるんですかね
# RT @nakaji32: あﾞ〜、この辺が原因でエクセルマクロは展開しなくなったなぁ。自分でこっそり使う程度になりました。
# 又貸し・又展開されるとあっという間に手に負えなくなる。でも使われてるマクロかるんだろうなぁ、、、元気にしてるかなぁあの子💭
# RT @kubokenkuboken: その自転車を有償で売ったり、似た自転車作って売ったり、その自転車でレンタルサイクルして商売したりというのは見かけたことがある。
# RT @karin_infra: わかるわ～
# いままでよしなにやってくれてたのに、そこは頑ななんだね・・ってなるｗ
# シリアル値で指示するドーラ
# 「TIME(0,0,40)で支度しな！」
# 自転車を勝手に持ち出された挙げ句「運転していたらケガをした」「なぜ鍵をかけていなかった」と怒られるのと同等の理不尽を自作マクロで味わう
# @0612Xlookup3 なんかうまいことやった感あって好きです
# first_flg: False
# @571008910fukkie 係長から問い合わせを受ける人が…
# パソコン
# 「そろそろ定時だから不具合起こすか」
# RT @Tsutsui0524: 木簡から紙に移り変わる時も、木簡で読まないと読んだ気にならないとか言われていたんですかねえ
# 私「今日1/6って入れたら2023年のことだと思わない！？」
#
# Excel「微塵も思いませんな」
# では御覧ください
# 『セルを結合して紂王』 https://t.co/O1sSVd5Ofg
# @trc_games 南無！！ってやったら通じたので感動しました笑
# 感動を覚えたパソコン操作
#
# マウスの左ボタンで閉じるボタンを押しこむ
# ↓
# しまった！
# ↓
# 左ボタンを押したままポインタをずらして左ボタンを放す
# ↓
# キャンセル成功
# Excelの数式の一部を選択した状態でF9キーを押すと、選択部分が評価されて検証に便利です！
# 『Ctrl + Z』か『Esc』で元の数式に戻すことができます
#
# 編集まわりのテクニックを覚えると作業が捗りますね https://t.co/JqDbUuDjKO
# @TETRA_IT ボールはパートナー…
# @WJQnQtt3oa376i2 置き場所、形式バラバラでは不便ですもんね
# first_flg: False
# RT @ExcelVBAer: 一回でいいからVBEアドインを入れてみてください.!.!.
# RT @ExcelHumor: when you hard code a number into a formula https://t.co/r92DxVhXUF
# @rootassist 過去の効率化が積み重なった今を評価して欲しいと思うことがたまに…笑
# RT @baruojiobenkyo: これ知ってました？エクセルで「Ctrl&amp;+」で列や行の挿入がショートカットできますよね。複数の行または列を選択してからこれをすると、その数だけ挿入できるんですって。今まで連打してました…
# ショートカットは大体知ってると思ってましたけど奥が…
# これこれ、こういうの好きです https://t.co/aKLzRcKlcj
# 私のライバルは昨日の私です
#
# 明日の私のために今日、いかに駄目でいられるか。
# 日々挑戦ですよね。
#
# 無茶はしません。
# 一度無茶をすると、明日以降にツケが回ってきますから。
#
# 明日の自分の眼前に悠々と寝そべる今日の自分でありたい、それだけです。
# @sugoi_kaizen 良い内容になる気しかしないですね
# 正座して読まないといけないやつ…！！
# @Bug1978 それやってないと確実に抜かすので必須ですね
# RT @Bug1978: 気持ちは分かるｗ
# でも、どうしても持ち越しになった場合に、休み明けの自分へ向けたメモを机に置いて帰るのは私だけだろうか？ｗ
# 一回でいいからVBEを開いてみてください…！！ https://t.co/2IsGp4ZFCY
# first_flg: False
# 最後のページに到達しました
# 取得したデータ数：3236

# %%
labels=[
'ツイートID',
'ツイート本文'
]
csvize(tw_data,username,labels,"account_tweet")

# %%
tw_data = []
next_token = ""
first_flg = True

while True:
    if first_flg == True:
        print("first_flg: " + str(first_flg))
        #1回目リクエスト    
        tweets = client.get_home_timeline()
        first_flg = False
    else:
        #2回目リクエスト    
        tweets = client.get_home_timeline(pagination_token=next_token)
    try:
        next_token = tweets[3]['next_token']
        print("next_token: " + next_token)
    except KeyError:
        #next_tokenが取得できない（最後のリクエスト）の場合はループ終了
        print("最後のページに到達しました")
        break
    for tweet in tweets.data:
            tw_data.append([
            tweet.id,
            tweet.text,])
print(f"取得したツイート数：{len(tw_data)}")
# Out:
# first_flg: True
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9080\1113706750.py in <module>
#       7         print("first_flg: " + str(first_flg))
#       8         #1回目リクエスト
# ----> 9         tweets = client.get_home_timeline()
#      10         first_flg = False
#      11     else:
#
# ~\Anaconda3\lib\site-packages\tweepy\client.py in get_home_timeline(self, user_auth, **params)
#    1471         route = f"/2/users/{id}/timelines/reverse_chronological"
#    1472
# -> 1473         return self._make_request(
#    1474             "GET", route, params=params,
#    1475             endpoint_parameters=(
#
# ~\Anaconda3\lib\site-packages\tweepy\client.py in _make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     127         request_params = self._process_params(params, endpoint_parameters)
#     128
# --> 129         response = self.request(method, route, params=request_params,
#     130                                 json=json, user_auth=user_auth)
#     131
#
# ~\Anaconda3\lib\site-packages\tweepy\client.py in request(self, method, route, params, json, user_auth)
#     113                     return self.request(method, route, params, json, user_auth)
#     114                 else:
# --> 115                     raise TooManyRequests(response)
#     116             if response.status_code >= 500:
#     117                 raise TwitterServerError(response)
#
# TooManyRequests: 429 Too Many Requests
# Too Many Requests

# %%
labels=[
'ツイートID',
'ツイート本文'
# 'いいね数',
# 'リツイート数',
# # 'ID',
# 'ユーザー名',
# 'アカウント名',
]
csvize(tw_data,username,labels,"account_timeline")
